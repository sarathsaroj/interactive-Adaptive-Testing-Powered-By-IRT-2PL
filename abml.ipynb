# %%
## Adaptive Testing 

import openai
from openai import OpenAI
import os
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings("ignore")

# %%
os.environ["OPENAI_API_KEY"] = "sk-proj-fPbd82pXUd0snI5DTCSYT3BlbkFJNT1ZqfvGxFa1K1Pz3bJG"
def generate_questions(prompt, num_questions=10):
    try:
        api_key = os.getenv("OPENAI_API_KEY")
        if not api_key:
            raise ValueError("OPENAI_API_KEY environment variable not set.")

        client = OpenAI(api_key=api_key)
        generated_texts = set()
        questions = []
        i = 0

        while i < num_questions:
            variation_prompt = f"{prompt} - Question {i+1}"

            response = client.completions.create(
                model="gpt-3.5-turbo-instruct",
                prompt=f"Generate a multiple-choice question about {variation_prompt} strictly in the format:\n\n" \
                       f"Question:\n" \
                       f"Option A:\n" \
                       f"Option B:\n" \
                       f"Option C:\n" \
                       f"Option D:\n" \
                       f"Correct Option: Option A or Option B or Option C or Option D",
                max_tokens=150,
                n=1,
                stop=None,
                temperature=0.9
            )

            question_text = response.choices[0].text.strip()

            if question_text in generated_texts:
                continue

            generated_texts.add(question_text)

            lines = question_text.splitlines()
            lines = [line.strip() for line in lines if line.strip()]

            if not (lines[0].startswith('Question') and lines[1].startswith('Option A') and
                    lines[2].startswith('Option B') and lines[3].startswith('Option C') and
                    lines[4].startswith('Option D') and lines[5].startswith('Correct')):
                continue

            question_data = {
                "Question": lines[0].replace("Question:", "").strip(),
                "Category": prompt,
                "Option A": lines[1].replace("Option A:", "").strip(),
                "Option B": lines[2].replace("Option B:", "").strip(),
                "Option C": lines[3].replace("Option C:", "").strip(),
                "Option D": lines[4].replace("Option D:", "").strip(),
                "Correct Option": lines[5].replace("Correct Option:", "").strip()[0:8],
                'difficulty_index': np.random.uniform(0.1, 1.0),
                'discriminatory_index': np.random.uniform(0.1, 1.0),
            }

            questions.append(question_data)
            i += 1

        questions_df = pd.DataFrame(questions)
        return questions_df

    except ValueError as ve:
        print(f"ValueError: {ve}")
        return None
    except Exception as e:
        print(f"An error occurred: {e}")
        return None

# %%
# Prompts to generate questions
prompts = ["Biology", "Psychology", "Gynaecology", "Oncology", "Orthopedic"]
questions_df_list = [generate_questions(prompt, num_questions=10) for prompt in prompts]
all_questions_df = pd.concat(questions_df_list, ignore_index=True)

if all_questions_df is not None:
    print("Generated Questions:")
    print(all_questions_df)
else:
    print("Failed to generate questions.")

all_questions_df=all_questions_df.reset_index().rename(columns={'index':'question_id'})

questions_list = all_questions_df.to_dict(orient='records')
# Out:
# Generated Questions:
#                                              Question     Category  \
# 0   What is the process by which plants produce food?      Biology
# 1        Which of the following is NOT a type of RNA?      Biology
# 2   Which of the following is NOT a characteristic...      Biology
# 3   What is the process by which plants use sunlig...      Biology
# 4   Which of the following organelles is responsib...      Biology
# 5   What is the process by which plants convert su...      Biology
# 6   In humans, which organ is responsible for prod...      Biology
# 7   What is the process by which DNA is copied for...      Biology
# 8   Which of the following is NOT a function of th...      Biology
# 9   What organelle is responsible for the producti...      Biology
# 10  What is the scientific study of the mind and b...   Psychology
# 11  What is the study of how individuals perceive,...   Psychology
# 12  What is the primary focus of cognitive psychol...   Psychology
# 13  What is the term for the phenomenon where indi...   Psychology
# 14  According to Freud's psychoanalytic theory, wh...   Psychology
# 15  Which of the following areas is NOT a subfield...   Psychology
# 16  What is the correct order of the stages in Mas...   Psychology
# 17  What is the process of obtaining, organizing, ...   Psychology
# 18  Which type of therapy focuses on changing nega...   Psychology
# 19  What is the term for the process of releasing ...   Psychology
# 20  Which of the following is NOT a common symptom...  Gynaecology
# 21  What is the most common cause of abnormal vagi...  Gynaecology
# 22  What is the average length of a woman's menstr...  Gynaecology
# 23  What is the average duration of a menstrual cy...  Gynaecology
# 24  What is the recommended age for women to start...  Gynaecology
# 25  What is the most common form of birth control ...  Gynaecology
# 26  What is the medical term for the shedding of t...  Gynaecology
# 27  When should a woman start receiving regular gy...  Gynaecology
# 28  What is the most common method used for detect...  Gynaecology
# 29      What is the most common type of ovarian cyst?  Gynaecology
# 30  Which of the following is NOT a common type of...     Oncology
# 31  What is the most common type of cancer diagnos...     Oncology
# 32  What type of cancer occurs in the cells of the...     Oncology
# 33  What is the most common type of cancer among w...     Oncology
# 34  Which of the following is a common risk factor...     Oncology
# 35  Which of the following is NOT a common treatme...     Oncology
# 36  What is the most common type of cancer that af...     Oncology
# 37  Question 8: What is the most commonly diagnose...     Oncology
# 38  What is the most common type of cancer diagnos...     Oncology
# 39     What is the most common type of cancer in men?     Oncology
# 40  Which of the following is NOT a common conditi...   Orthopedic
# 41  What is the most common cause of a rotator cuf...   Orthopedic
# 42  Which of the following is a common condition t...   Orthopedic
# 43  What is the most common type of orthopedic sur...   Orthopedic
# 44  What type of medical professional specializes ...   Orthopedic
# 45  What is the most common cause of orthopedic in...   Orthopedic
# 46  What is the most common condition treated by o...   Orthopedic
# 47  What is the most common reason for someone to ...   Orthopedic
# 48  What is the most common type of fracture treat...   Orthopedic
# 49  Which of the following is NOT a common treatme...   Orthopedic
#
#                                              Option A  \
# 0                                      Photosynthesis
# 1                                       Messenger RNA
# 2                                        Reproduction
# 3                                      Photosynthesis
# 4                                     Golgi apparatus
# 5                                      Photosynthesis
# 6                                               Liver
# 7                                         Translation
# 8   Regulates the movement of substances in and ou...
# 9                                             Nucleus
# 10                                          Sociology
# 11                           Developmental psychology
# 12  Understanding how unconscious desires influenc...
# 13                                  Self-serving bias
# 14                                 The conscious mind
# 15                               Cognitive psychology
# 16  Self-actualization, esteem, love/belonging, sa...
# 17                                         Perception
# 18                                 Humanistic therapy
# 19                                    Rationalization
# 20                                    Painful periods
# 21                                      Endometriosis
# 22                                            21 days
# 23                                            21 days
# 24                                    25-29 years old
# 25                                            Condoms
# 26                                       Endometritis
# 27                                          At age 18
# 28                                          Pap smear
# 29                                       Dermoid cyst
# 30                                        Lung cancer
# 31                                        Lung cancer
# 32                                           Leukemia
# 33                                      Breast cancer
# 34                                            Smoking
# 35                                            Surgery
# 36                                      Breast cancer
# 37                                      Breast cancer
# 38                                        Lung cancer
# 39                                    Prostate cancer
# 40                                          Arthritis
# 41                                   Traumatic injury
# 42                                             Asthma
# 43                                   Knee replacement
# 44                                       Orthodontist
# 45                           Age-related degeneration
# 46                                          Fractures
# 47                                          Arthritis
# 48                                    Stress fracture
# 49                                            Surgery
#
#                                              Option B  \
# 0                                         Respiration
# 1                                        Transfer RNA
# 2                                          Metabolism
# 3                                         Respiration
# 4                                             Nucleus
# 5                                             Mitosis
# 6                                              Kidney
# 7                                       Transcription
# 8          Provides structure and support to the cell
# 9                                        Mitochondria
# 10                                       Anthropology
# 11                                  Social psychology
# 12  Studying the effects of reinforcement on behavior
# 13                                  Confirmation bias
# 14                              The preconscious mind
# 15                                Clinical psychology
# 16  Physiological, safety, love/belonging, esteem,...
# 17                                             Memory
# 18                       Cognitive-behavioral therapy
# 19                                         Projection
# 20                           Heavy menstrual bleeding
# 21                                          Pregnancy
# 22                                            28 days
# 23                                            28 days
# 24                                    30-39 years old
# 25                                Oral contraceptives
# 26                                       Dysmenorrhea
# 27                                          At age 25
# 28                                        Breast exam
# 29                                  Endometrioma cyst
# 30                                      Breast cancer
# 31                                    Prostate cancer
# 32                                        Skin Cancer
# 33                                        Lung cancer
# 34                                 Eating fried foods
# 35                                       Chemotherapy
# 36                                        Lung cancer
# 37                                        Lung cancer
# 38                                    Prostate cancer
# 39                                        Lung cancer
# 40                                       Broken bones
# 41                                           Genetics
# 42                                       Hypertension
# 43                                       Bunionectomy
# 44                                 Orthopedic surgeon
# 45                                  Sports activities
# 46                                     Osteoarthritis
# 47                                          Scoliosis
# 48                                Comminuted fracture
# 49                                               Cast
#
#                                              Option C  \
# 0                                        Fermentation
# 1                                       Ribosomal RNA
# 2                                         Homeostasis
# 3                                       Transpiration
# 4                               Endoplasmic reticulum
# 5                                         Respiration
# 6                                            Pancreas
# 7                                         Replication
# 8   Converts sunlight into energy through photosyn...
# 9                                     Golgi Apparatus
# 10                                         Psychology
# 11                               Cognitive psychology
# 12         Exploring the role of genetics in behavior
# 13                      Fundamental attribution error
# 14                               The unconscious mind
# 15                               Political psychology
# 16  Self-actualization, physiological, safety, lov...
# 17                                           Learning
# 18                              Psychodynamic therapy
# 19                                        Sublimation
# 20                     Pelvic pain during intercourse
# 21                        Pelvic inflammatory disease
# 22                                            35 days
# 23                                            35 days
# 24                                    40-49 years old
# 25                                               IUDs
# 26                                        Menorrhagia
# 27                   When she becomes sexually active
# 28                                         Ultrasound
# 29                                    Follicular cyst
# 30                                    Prostate cancer
# 31                                  Colorectal cancer
# 32                                    Prostate Cancer
# 33                                       Colon cancer
# 34                               Exercising regularly
# 35                                      Immunotherapy
# 36                                    Prostate cancer
# 37                                  Colorectal cancer
# 38                                       Colon cancer
# 39                                       Colon cancer
# 40                                      Heart disease
# 41                                              Aging
# 42                                          Arthritis
# 43                                      Spinal fusion
# 44                      Orthopedic nurse practitioner
# 45                                      Car accidents
# 46                             Carpal Tunnel Syndrome
# 47                                    Dental problems
# 48                                Greenstick fracture
# 49                                   Physical therapy
#
#                                              Option D Correct Option  \
# 0                                           Digestion       Option A
# 1                               Deoxyribonucleic acid       Option D
# 2                                             Inertia       Option D
# 3                                             Mitosis       Option A
# 4                                        Mitochondria       Option D
# 5                                        Fermentation       Option A
# 6                                             Stomach       Option C
# 7                                            Mutation       Option C
# 8             Facilitates communication between cells       Option C
# 9                                           Ribosomes       Option B
# 10                                          Economics       Option C
# 11                                Clinical psychology       Option C
# 12  Examining mental processes such as memory, thi...       Option D
# 13                               Cognitive dissonance       Option C
# 14                         The collective unconscious       Option C
# 15                           Developmental psychology              C
# 16  Love/belonging, safety, physiological, esteem,...       Option B
# 17                                         Motivation       Option A
# 18                                    Gestalt therapy       Option B
# 19                                         Regression       Option D
# 20                                        Infertility       Option D
# 21                                    Cervical cancer       Option B
# 22                                            42 days       Option B
# 23                                            42 days       Option B
# 24                                    50-59 years old       Option B
# 25                                         Abstinence       Option B
# 26                                       Menstruation       Option D
# 27                                  When she turns 30       Option A
# 28                                        Colonoscopy       Option A
# 29                                   Hemorrhagic cyst       Option C
# 30                                        Skin cancer       Option D
# 31                                        Skin cancer       Option B
# 32                                      Breast Cancer       Option A
# 33                                     Ovarian cancer       Option A
# 34                                   Drinking alcohol       Option A
# 35                                        Acupuncture       Option D
# 36                                     Ovarian cancer       Option C
# 37                                        Skin cancer       Option A
# 38                                        Skin cancer       Option B
# 39                                        Skin cancer       Option A
# 40                                    Sports injuries       Option C
# 41                                       Poor posture       Option C
# 42                                           Diabetes       Option C
# 43                                        Arthroscopy       Option A
# 44                                       Obstetrician       Option B
# 45                                              Falls       Option B
# 46                                  Plantar Fasciitis       Option A
# 47                                        Eye disease       Option A
# 48                                   Oblique fracture       Option A
# 49                                        Antibiotics              D
#
#     difficulty_index  discriminatory_index
# 0           0.966265              0.668603
# 1           0.311412              0.635955
# 2           0.427929              0.506619
# 3           0.643558              0.328614
# 4           0.643929              0.700294
# 5           0.717523              0.322159
# 6           0.563890              0.226074
# 7           0.188033              0.778001
# 8           0.352301              0.355100
# 9           0.219643              0.253148
# 10          0.533319              0.737625
# 11          0.645353              0.971440
# 12          0.681397              0.987256
# 13          0.791121              0.240467
# 14          0.772556              0.128671
# 15          0.466940              0.418617
# 16          0.569459              0.529261
# 17          0.358384              0.223235
# 18          0.422561              0.399963
# 19          0.434654              0.855876
# 20          0.917136              0.700630
# 21          0.560842              0.136063
# 22          0.728694              0.773667
# 23          0.330412              0.366944
# 24          0.800787              0.103560
# 25          0.881929              0.342531
# 26          0.308683              0.728034
# 27          0.555332              0.653387
# 28          0.940901              0.437413
# 29          0.367130              0.596717
# 30          0.313625              0.486319
# 31          0.107285              0.395540
# 32          0.174431              0.556699
# 33          0.545982              0.142670
# 34          0.631621              0.895423
# 35          0.977702              0.305255
# 36          0.317617              0.641700
# 37          0.261259              0.227828
# 38          0.551752              0.819253
# 39          0.840605              0.298430
# 40          0.126036              0.383388
# 41          0.705594              0.811292
# 42          0.995563              0.726655
# 43          0.508956              0.455295
# 44          0.268897              0.905335
# 45          0.644400              0.748215
# 46          0.475609              0.611333
# 47          0.434309              0.196272
# 48          0.355557              0.496221
# 49          0.533050              0.695679

# %%
import pulp
import ipywidgets as widgets
from IPython.display import display, clear_output
from functools import partial

class AdaptiveTest:
    def __init__(self, questions, total_questions=5):
        self.questions = questions
        self.total_questions = total_questions
        self.asked_questions = []
        self.correct_answers = 0
        self.correct_difficulty_indices = []
        self.current_difficulty = 0.5  # Starting difficulty index
        self.categories = list(set(q['Category'] for q in questions))

    def adjust_difficulty(self, previous_difficulty, correct):
        if correct:
            return min(1.0, previous_difficulty + 0.1)
        else:
            return max(0.1, previous_difficulty - 0.1)

    def setup_milp_model(self, available_questions, category_counts):
        model = pulp.LpProblem("Question_Selection", pulp.LpMaximize)
        x = pulp.LpVariable.dicts("x", range(len(available_questions)), cat="Binary")
        
        # Objective: Maximize the discriminatory index
        model += pulp.lpSum([available_questions[i]['discriminatory_index'] * x[i] for i in range(len(available_questions))])
        
        # Constraints: Ensure 20% ± 5% category representation for the remaining questions
        remaining_questions = self.total_questions - len(self.asked_questions)
        for cat in self.categories:
            category_indices = [i for i in range(len(available_questions)) if available_questions[i]['Category'] == cat]
            min_cat = max(0, 0.15 * remaining_questions - category_counts[cat])
            max_cat = min(len(category_indices), 0.25 * remaining_questions - category_counts[cat])
            #model += pulp.lpSum([x[i] for i in category_indices]) >= min_cat
            #model += pulp.lpSum([x[i] for i in category_indices]) <= max_cat
        
        # Ensure only one question is selected
        model += pulp.lpSum([x[i] for i in range(len(available_questions))]) == 1
        
        return model, x

    def get_next_question(self):
        available_questions = [q for q in self.questions if q['question_id'] not in self.asked_questions and 
                               abs(q['difficulty_index'] - self.current_difficulty) <= 0.2]

        if not available_questions:
            print("No more questions available with the current difficulty settings.")
            return None

        # Select a question ensuring 20% ± 5% category representation
        category_counts = {cat: 0 for cat in self.categories}
        for q_id in self.asked_questions:
            category_counts[self.questions[q_id]['Category']] += 1

        model, x = self.setup_milp_model(available_questions, category_counts)
        # **MISSING LINE:** Solve the MILP model
        model.solve() 
        
        selected_question_indices = [i for i in range(len(available_questions)) if pulp.value(x[i]) == 1]
        
        if not selected_question_indices:
            print("No feasible solution found by the MILP model. Relaxing constraints.")
            self.current_difficulty = self.adjust_difficulty(self.current_difficulty, False)
            return self.get_next_question()
        
        selected_question_index = selected_question_indices[0]
        selected_question = available_questions[selected_question_index]
        self.asked_questions.append(selected_question['question_id'])
        
        return selected_question

    def ask_question(self, question):
        clear_output(wait=True)  # Clear output before printing question
        print(f"Question: {question['Question']}, Category: {question['Category']}")  # Print the question
        option_buttons = []
        for idx, option in enumerate([question['Option A'], question['Option B'], question['Option C'], question['Option D']]):
            button = widgets.Button(description=f"{chr(65+idx)}: {option}")
            button.on_click(partial(self.check_answer, question, chr(65+idx)))
            option_buttons.append(button)
            button.layout.width = 'auto'
            display(button)  # Display the options

    def check_answer(self, question, answer, b):
        correct_option_letter = question['Correct Option'][-1]  # Get the last character (A, B, C, or D)
        correct = (answer == correct_option_letter) 
        if correct:
            self.correct_answers += 1
            self.correct_difficulty_indices.append(question['difficulty_index'])
        
        self.current_difficulty = self.adjust_difficulty(self.current_difficulty, correct)
        
        if len(self.asked_questions) < self.total_questions:
            next_question = self.get_next_question()
            if next_question:
                self.ask_question(next_question)
            else:
                self.finish_test()
        else:
            self.finish_test()

    def finish_test(self):
        clear_output(wait=True)
        final_score = sum(self.correct_difficulty_indices)
        print(f"Test completed! You answered {self.correct_answers} out of {self.total_questions} questions correctly.")
        print(f"Your final score is: {final_score:.2f}")

    def start_test(self):
        self.correct_answers = 0
        self.asked_questions = []
        self.correct_difficulty_indices = []
        self.current_difficulty = 0.5  # Reset starting difficulty
        first_question = self.get_next_question()
        if first_question:
            self.ask_question(first_question)

# Initialize the AdaptiveTest class with the questions
test = AdaptiveTest(questions_list)
test.start_test()

# %%
import pulp
import ipywidgets as widgets
from IPython.display import display, clear_output
from functools import partial
import math

class AdaptiveTest:
    def __init__(self, questions, total_questions=5):
        self.questions = questions
        self.total_questions = total_questions
        self.asked_questions = []
        self.correct_answers = 0
        self.correct_difficulty_indices = []
        self.current_ability = 0.5  # Starting ability level
        self.categories = list(set(q['Category'] for q in questions))

    def adjust_ability(self, previous_ability, question, correct):
        discrimination = question['discriminatory_index']
        difficulty = question['difficulty_index']
        if correct:
            return previous_ability + 0.1 * discrimination * (1 - self.calculate_2pl_probability(previous_ability, difficulty, discrimination))
        else:
            return previous_ability - 0.1 * discrimination * self.calculate_2pl_probability(previous_ability, difficulty, discrimination)

    def calculate_2pl_probability(self, ability, difficulty, discrimination):
        return 1 / (1 + math.exp(-discrimination * (ability - difficulty)))

    def setup_milp_model(self, available_questions, category_counts):
        model = pulp.LpProblem("Question_Selection", pulp.LpMaximize)
        x = pulp.LpVariable.dicts("x", range(len(available_questions)), cat="Binary")
        
        # Objective: Maximize the discriminatory index
        model += pulp.lpSum([available_questions[i]['discriminatory_index'] * x[i] for i in range(len(available_questions))])
        
        # Constraints: Ensure 20% ± 5% category representation for the remaining questions
        remaining_questions = self.total_questions - len(self.asked_questions)
        for cat in self.categories:
            category_indices = [i for i in range(len(available_questions)) if available_questions[i]['Category'] == cat]
            min_cat = max(0, 0.15 * remaining_questions - category_counts[cat])
            max_cat = min(len(category_indices), 0.25 * remaining_questions - category_counts[cat])
            #model += pulp.lpSum([x[i] for i in category_indices]) >= min_cat
            #model += pulp.lpSum([x[i] for i in category_indices]) <= max_cat
        
        # Ensure only one question is selected
        model += pulp.lpSum([x[i] for i in range(len(available_questions))]) == 1
        
        return model, x

    def get_next_question(self):
        available_questions = [q for q in self.questions if q['question_id'] not in self.asked_questions and 
                            abs(q['difficulty_index'] - self.current_ability) <= 0.2]

        if not available_questions:
            print("No more questions available with the current difficulty settings.")
            return None

        # Select a question ensuring 20% ± 5% category representation
        category_counts = {cat: 0 for cat in self.categories}
        for q_id in self.asked_questions:
            category_counts[self.questions[q_id]['Category']] += 1

        model, x = self.setup_milp_model(available_questions, category_counts)
        
        # Solve the MILP model
        model.solve() 
        
        selected_question_indices = [i for i in range(len(available_questions)) if pulp.value(x[i]) == 1]
        
        if not selected_question_indices:
            print("No feasible solution found by the MILP model. Relaxing constraints.")
            # Choose the first available question for simplicity
            fallback_question = available_questions[0]
            self.current_ability = self.adjust_ability(self.current_ability, fallback_question, False)
            return self.get_next_question()
        
        selected_question_index = selected_question_indices[0]
        selected_question = available_questions[selected_question_index]
        self.asked_questions.append(selected_question['question_id'])
        
        return selected_question

    def ask_question(self, question):
        clear_output(wait=True)  # Clear output before printing question
        print(f"Question: {question['Question']}, Category: {question['Category']}")  # Print the question
        option_buttons = []
        for idx, option in enumerate([question['Option A'], question['Option B'], question['Option C'], question['Option D']]):
            button = widgets.Button(description=f"{chr(65+idx)}: {option}")
            button.on_click(partial(self.check_answer, question, chr(65+idx)))
            option_buttons.append(button)
            button.layout.width = 'auto'
            display(button)  # Display the options

    def check_answer(self, question, answer, b):
        correct_option_letter = question['Correct Option'][-1]  # Get the last character (A, B, C, or D)
        correct = (answer == correct_option_letter) 
        if correct:
            self.correct_answers += 1
            self.correct_difficulty_indices.append(question['difficulty_index'])
        
        self.current_ability = self.adjust_ability(self.current_ability, question, correct)
        
        if len(self.asked_questions) < self.total_questions:
            next_question = self.get_next_question()
            if next_question:
                self.ask_question(next_question)
            else:
                self.finish_test()
        else:
            self.finish_test()

    def finish_test(self):
        clear_output(wait=True)
        final_score = sum(self.correct_difficulty_indices)
        print(f"Test completed! You answered {self.correct_answers} out of {self.total_questions} questions correctly.")
        print(f"Your final score is: {final_score:.2f}")

    def start_test(self):
        self.correct_answers = 0
        self.asked_questions = []
        self.correct_difficulty_indices = []
        self.current_ability = 0.5  # Reset starting ability level
        first_question = self.get_next_question()
        if first_question:
            self.ask_question(first_question)

# Initialize the AdaptiveTest class with the questions
test = AdaptiveTest(questions_list,total_questions=3)
test.start_test()

import pulp
import ipywidgets as widgets
from IPython.display import display, clear_output
from functools import partial
import math
import pyirt  # Import the pyirt library

class AdaptiveTest:
    def __init__(self, questions, total_questions=5):
        self.questions = questions
        self.total_questions = total_questions
        self.asked_questions = []
        self.correct_answers = 0
        self.correct_difficulty_indices = []  # Store correct difficulty indices for score calculation
        self.current_ability = 0.5  # Starting ability level
        self.categories = list(set(q['Category'] for q in questions))

    def adjust_ability(self, previous_ability, question, correct):
        # Adjust ability using a simple method for now
        # In a production setting, you would use MLE/MMLE from pyirt
        discrimination = question['discriminatory_index']
        difficulty = question['difficulty_index']
        if correct:
            return previous_ability + 0.1 * discrimination * (1 - self.calculate_2pl_probability(previous_ability, difficulty, discrimination))
        else:
            return previous_ability - 0.1 * discrimination * self.calculate_2pl_probability(previous_ability, difficulty, discrimination)

    def calculate_2pl_probability(self, ability, difficulty, discrimination):
        return 1 / (1 + math.exp(-discrimination * (ability - difficulty)))

    def setup_milp_model(self, available_questions, category_counts):
        model = pulp.LpProblem("Question_Selection", pulp.LpMaximize)
        x = pulp.LpVariable.dicts("x", range(len(available_questions)), cat="Binary")

        # Objective: Maximize the discriminatory index
        model += pulp.lpSum([available_questions[i]['discriminatory_index'] * x[i] for i in range(len(available_questions))])

        # Constraints: Ensure 20% ± 5% category representation for the remaining questions
        remaining_questions = self.total_questions - len(self.asked_questions)
        for cat in self.categories:
            category_indices = [i for i in range(len(available_questions)) if available_questions[i]['Category'] == cat]
            min_cat = max(0, 0.15 * remaining_questions - category_counts[cat])
            max_cat = min(len(category_indices), 0.25 * remaining_questions - category_counts[cat])
            model += pulp.lpSum([x[i] for i in category_indices]) >= min_cat
            model += pulp.lpSum([x[i] for i in category_indices]) <= max_cat

        # Ensure only one question is selected
        model += pulp.lpSum([x[i] for i in range(len(available_questions))]) == 1

        return model, x

    def get_next_question(self):
        available_questions = [q for q in self.questions if q['question_id'] not in self.asked_questions and
                               abs(q['difficulty_index'] - self.current_ability) <= 0.2]

        if not available_questions:
            print("No more questions available with the current difficulty settings.")
            return None

        # Select a question ensuring 20% ± 5% category representation
        category_counts = {cat: 0 for cat in self.categories}
        for q_id in self.asked_questions:
            category_counts[self.questions[q_id]['Category']] += 1

        model, x = self.setup_milp_model(available_questions, category_counts)
        model.solve()

        selected_question_indices = [i for i in range(len(available_questions)) if pulp.value(x[i]) == 1]

        if not selected_question_indices:
            print("No feasible solution found by the MILP model. Relaxing constraints.")
            self.current_ability = self.adjust_ability(self.current_ability, False, False)  # Pass False for 'correct'
            return self.get_next_question()

        selected_question_index = selected_question_indices[0]
        selected_question = available_questions[selected_question_index]
        self.asked_questions.append(selected_question['question_id'])

        return selected_question

    def ask_question(self, question):
        clear_output(wait=True)
        print(f"Question: {question['Question']}, Category: {question['Category']}")
        option_buttons = []
        for idx, option in enumerate([question['Option A'], question['Option B'], question['Option C'], question['Option D']]):
            button = widgets.Button(description=f"{chr(65+idx)}: {option}")
            button.on_click(partial(self.check_answer, question, chr(65+idx)))
            option_buttons.append(button)
            button.layout.width = 'auto'
            display(button)

    def check_answer(self, question, answer, b):
        correct_option_letter = question['Correct Option'][-1]
        correct = (answer == correct_option_letter)
        if correct:
            self.correct_answers += 1
            self.correct_difficulty_indices.append(question['difficulty_index'])  # Store the correct difficulty index for scoring

        # Update ability using IRT (2PL)
        self.current_ability = pyirt.estimate_ability(self.current_ability, question['discriminatory_index'], question['difficulty_index'], correct=correct)

        if len(self.asked_questions) < self.total_questions:
            next_question = self.get_next_question()
            if next_question:
                self.ask_question(next_question)
            else:
                self.finish_test()
        else:
            self.finish_test()

    def finish_test(self):
        clear_output(wait=True)
        final_score = sum(self.correct_difficulty_indices)
        print(f"Test completed! You answered {self.correct_answers} out of {self.total_questions} questions correctly.")
        print(f"Your final score is: {final_score:.2f}")

    def start_test(self):
        self.correct_answers = 0
        self.asked_questions = []
        self.correct_difficulty_indices = []
        self.current_ability = 0.5
        first_question = self.get_next_question()
        if first_question:
            self.ask_question(first_question)




test = AdaptiveTest(questions_list, total_questions=3)  # You can change the total questions
test.start_test()
