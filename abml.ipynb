# %%
## Adaptive Testing 

import openai
from openai import OpenAI
import os
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings("ignore")

# %%
os.environ["OPENAI_API_KEY"] = "sk-proj-fPbd82pXUd0snI5DTCSYT3BlbkFJNT1ZqfvGxFa1K1Pz3bJG"
def generate_questions(prompt, num_questions=10):
    try:
        api_key = os.getenv("OPENAI_API_KEY")
        if not api_key:
            raise ValueError("OPENAI_API_KEY environment variable not set.")

        client = OpenAI(api_key=api_key)
        generated_texts = set()
        questions = []
        i = 0

        while i < num_questions:
            variation_prompt = f"{prompt} - Question {i+1}"

            response = client.completions.create(
                model="gpt-3.5-turbo-instruct",
                prompt=f"Generate a multiple-choice question about {variation_prompt} strictly in the format:\n\n" \
                       f"Question:\n" \
                       f"Option A:\n" \
                       f"Option B:\n" \
                       f"Option C:\n" \
                       f"Option D:\n" \
                       f"Correct Option: Option A or Option B or Option C or Option D",
                max_tokens=150,
                n=1,
                stop=None,
                temperature=0.9
            )

            question_text = response.choices[0].text.strip()

            if question_text in generated_texts:
                continue

            generated_texts.add(question_text)

            lines = question_text.splitlines()
            lines = [line.strip() for line in lines if line.strip()]

            if not (lines[0].startswith('Question') and lines[1].startswith('Option A') and
                    lines[2].startswith('Option B') and lines[3].startswith('Option C') and
                    lines[4].startswith('Option D') and lines[5].startswith('Correct')):
                continue

            question_data = {
                "Question": lines[0].replace("Question:", "").strip(),
                "Category": prompt,
                "Option A": lines[1].replace("Option A:", "").strip(),
                "Option B": lines[2].replace("Option B:", "").strip(),
                "Option C": lines[3].replace("Option C:", "").strip(),
                "Option D": lines[4].replace("Option D:", "").strip(),
                "Correct Option": lines[5].replace("Correct Option:", "").strip()[0:8],
                'difficulty_index': np.random.uniform(0.1, 1.0),
                'discriminatory_index': np.random.uniform(0.1, 1.0),
            }

            questions.append(question_data)
            i += 1

        questions_df = pd.DataFrame(questions)
        return questions_df

    except ValueError as ve:
        print(f"ValueError: {ve}")
        return None
    except Exception as e:
        print(f"An error occurred: {e}")
        return None

# %%
# Prompts to generate questions
prompts = ["Biology", "Psychology", "Gynaecology", "Orthopedic","Oncology"]
questions_df_list = [generate_questions(prompt, num_questions=10) for prompt in prompts]
all_questions_df = pd.concat(questions_df_list, ignore_index=True)

if all_questions_df is not None:
    print("Generated Questions:")
    print(all_questions_df)
else:
    print("Failed to generate questions.")

all_questions_df=all_questions_df.reset_index().rename(columns={'index':'question_id'})
all_questions_df.to_csv('Questions.csv',header=True)
# Out:
# Generated Questions:
#                                              Question     Category  \
# 0   What is the process by which plants convert su...      Biology
# 1   Which of the following is the basic unit of li...      Biology
# 2   Which of the following organelles is responsib...      Biology
# 3   Which of the following is not a type of blood ...      Biology
# 4   Which of the following is a characteristic of ...      Biology
# 5   What is the function of a mitochondrion in a c...      Biology
# 6   Which of the following is NOT a function of th...      Biology
# 7   What is the process by which genetic informati...      Biology
# 8   Which of the following is the primary function...      Biology
# 9   What is the process by which plants use sunlig...      Biology
# 10  Which of the following is NOT a primary approa...   Psychology
# 11   What is the main focus of humanistic psychology?   Psychology
# 12  What is the primary focus of cognitive psychol...   Psychology
# 13  Which of the following statements accurately d...   Psychology
# 14  According to Freud's psychoanalytic theory, wh...   Psychology
# 15  According to the theory of operant conditionin...   Psychology
# 16  According to Freud's psychoanalytic theory, wh...   Psychology
# 17  Which of the following is NOT a major perspect...   Psychology
# 18  Which of the following is NOT one of the five ...   Psychology
# 19  What is the concept of "nature-nurture" in psy...   Psychology
# 20  Which of the following is a common symptom of ...  Gynaecology
# 21  What is the term for a condition in which the ...  Gynaecology
# 22  What is the primary function of the cervix in ...  Gynaecology
# 23  Which of the following is NOT a common symptom...  Gynaecology
# 24           What is the purpose of a Pap smear test?  Gynaecology
# 25  What is the most common type of cancer in the ...  Gynaecology
# 26  What is the primary responsibility of a gyneco...  Gynaecology
# 27  Which part of the female reproductive system s...  Gynaecology
# 28  What is the most common method for diagnosing ...  Gynaecology
# 29           What is the purpose of a Pap smear test?  Gynaecology
# 30  What is the most common type of surgery perfor...   Orthopedic
# 31  What is the most common type of injury treated...   Orthopedic
# 32  What is the most common type of surgery perfor...   Orthopedic
# 33   What is the main purpose of an orthopedic brace?   Orthopedic
# 34      What is the most common orthopedic condition?   Orthopedic
# 35  Which of the following is not a common conditi...   Orthopedic
# 36  What is the most common cause of a sprained an...   Orthopedic
# 37  What is the most common type of orthopedic inj...   Orthopedic
# 38  What is the most common cause of orthopedic in...   Orthopedic
# 39  What is the most common type of fracture seen ...   Orthopedic
# 40            What is the most common type of cancer?     Oncology
# 41     What is the most common type of cancer in men?     Oncology
# 42            What is the most common type of cancer?     Oncology
# 43  What is the most common type of cancer diagnos...     Oncology
# 44  Which of the following is NOT considered a com...     Oncology
# 45     What is the most common type of cancer in men?     Oncology
# 46  Which of the following is NOT a common type of...     Oncology
# 47  Which of the following is NOT a common treatme...     Oncology
# 48  What is the most common type of cancer in men ...     Oncology
# 49  Which of the following is NOT a common treatme...     Oncology
#
#                                              Option A  \
# 0                                      Photosynthesis
# 1                                                Cell
# 2                                             Nucleus
# 3                                    White blood cell
# 4                                     Ability to move
# 5                                Production of energy
# 6                                  Production of bile
# 7                                        Reproduction
# 8                                    Producing energy
# 9                                      Photosynthesis
# 10                                     Psychoanalytic
# 11                Understanding unconscious conflicts
# 12  The study of how individuals perceive and inte...
# 13  It is the study of mental illnesses and their ...
# 14                                             The Id
# 15                             Positive reinforcement
# 16                                                 Id
# 17                                          Cognitive
# 18                                         Humanistic
# 19  The debate over whether behavior is determined...
# 20          Severe abdominal pain during menstruation
# 21                                      Endometriosis
# 22                         To store and release sperm
# 23                           Heavy menstrual bleeding
# 24                      To screen for cervical cancer
# 25                                      Breast cancer
# 26  Perform surgery to treat gynecological conditions
# 27                                            Ovaries
# 28                                          Pap smear
# 29                      To screen for cervical cancer
# 30                                    Hip replacement
# 31                                            Sprains
# 32                                    Hip replacement
# 33                   To provide support and stability
# 34                                       Osteoporosis
# 35                                          Back pain
# 36                               Tripping and falling
# 37                                        Broken bone
# 38                                              Falls
# 39                                Comminuted fracture
# 40                                      Breast cancer
# 41                                        Lung cancer
# 42                                        Lung cancer
# 43                                        Lung cancer
# 44                                       Chemotherapy
# 45                                        Lung cancer
# 46                                        Lung cancer
# 47                                            Surgery
# 48                                        Lung cancer
# 49                                       Chemotherapy
#
#                                              Option B  \
# 0                                         Respiration
# 1                                                Atom
# 2                                        Mitochondria
# 3                                      Red blood cell
# 4                                Ability to reproduce
# 5                         Storage of genetic material
# 6                Detoxification of harmful substances
# 7                                      Photosynthesis
# 8                              Regulating cell growth
# 9                                Cellular respiration
# 10                                         Behavioral
# 11                       Studying observable behavior
# 12     The role of genetics in shaping human behavior
# 13  It is the scientific study of behavior and men...
# 14                                            The Ego
# 15                             Negative reinforcement
# 16                                     Superconscious
# 17                                         Behavioral
# 18                                        Behaviorist
# 19  The belief that individuals are born with inna...
# 20                                Nausea and vomiting
# 21                          Polycystic Ovary Syndrome
# 22                    To produce and secrete estrogen
# 23                                        Pelvic pain
# 24        To diagnose sexually transmitted infections
# 25                                     Ovarian cancer
# 26         Deliver babies and provide postpartum care
# 27                                             Vagina
# 28                                 Endometrial biopsy
# 29                            To check hormone levels
# 30                                      Brain surgery
# 31                                       Broken bones
# 32                                   Cataract surgery
# 33                   To correct posture and alignment
# 34                                          Arthritis
# 35                                  Plantar fasciitis
# 36                                 High impact sports
# 37                                      Torn ligament
# 38                                   Sport activities
# 39                                Greenstick fracture
# 40                                        Lung cancer
# 41                                    Prostate cancer
# 42                                      Breast cancer
# 43                                      Breast cancer
# 44                                  Radiation therapy
# 45                                    Prostate cancer
# 46                                      Breast cancer
# 47                                  Radiation therapy
# 48                                    Prostate cancer
# 49                                  Radiation therapy
#
#                                              Option C  \
# 0                                        Fermentation
# 1                                               Organ
# 2                                     Golgi apparatus
# 3                                            Platelet
# 4                             Ability to change color
# 5                              Transport of nutrients
# 6                  Regulation of blood glucose levels
# 7                                          Metabolism
# 8                         Storing genetic information
# 9                                             Meiosis
# 10                                           Eclectic
# 11                         Examining mental processes
# 12  The impact of social interactions on personali...
# 13  It is the practice of using hypnosis to treat ...
# 14                                       The Superego
# 15                                         Punishment
# 16                                                Ego
# 17                                     Psychoanalytic
# 18                                          Cognitive
# 19  The study of how the environment shapes a pers...
# 20                                         High fever
# 21                                           Fibroids
# 22        To support and protect the developing fetus
# 23                        Difficulty getting pregnant
# 24            To monitor the progression of pregnancy
# 25                                 Endometrial cancer
# 26   Conduct fertility treatments and hormone therapy
# 27                                             Uterus
# 28                                         Ultrasound
# 29                          To diagnose ovarian cysts
# 30                                   Cosmetic surgery
# 31                                         Tendonitis
# 32                                     Gastric bypass
# 33                   To relieve pain and inflammation
# 34                                          Scoliosis
# 35                                          Cataracts
# 36                                      Poor footwear
# 37                                     Sprained ankle
# 38                                      Car accidents
# 39                                    Spiral fracture
# 40                                    Prostate cancer
# 41                                  Colorectal cancer
# 42                                    Prostate cancer
# 43                                       Colon cancer
# 44                                      Immunotherapy
# 45                                       Colon cancer
# 46                                        Skin cancer
# 47                                       Chemotherapy
# 48                                  Colorectal cancer
# 49                                 Antibiotic therapy
#
#                                              Option D Correct Option  \
# 0                                             Osmosis       Option A
# 1                                            Molecule       Option A
# 2                                           Ribosomes       Option D
# 3                                           Stem cell       Option D
# 4                            Ability to create energy       Option B
# 5                              Protection of the cell       Option A
# 6                            Production of antibodies       Option D
# 7                                           Diffusion       Option A
# 8                      Detoxifying harmful substances       Option A
# 9                                             Mitosis       Option A
# 10                                      Physiological       Option D
# 11          Emphasizing personal growth and potential       Option D
# 12  The physiological processes involved in decisi...       Option A
# 13  It is the study of personality and how it rela...       Option B
# 14                                      The Conscious       Option A
# 15                                         Extinction       Option A
# 16                                           Superego       Option B
# 17                                          Religious       Option D
# 18                                         Biological       Option D
# 19  The idea that nature and nurture are two separ...       Option A
# 20                      Dizziness and lightheadedness       Option A
# 21                                         Cervicitis       Option A
# 22        To regulate and control the menstrual cycle       Option A
# 23                                    Lower back pain       Option D
# 24                       To evaluate fertility issues       Option A
# 25                                    Cervical cancer       Option D
# 26  Diagnose and treat sexually transmitted infect...       Option B
# 27                                    Fallopian tubes       Option A
# 28                                          Mammogram       Option C
# 29                            To detect endometriosis       Option A
# 30                                     Dental surgery       Option A
# 31                                          Arthritis       Option B
# 32                                         Root canal       Option A
# 33         To improve muscle strength and flexibility       Option A
# 34                                           Bursitis       Option B
# 35                                     Osteoarthritis       Option C
# 36                                           Genetics       Option A
# 37                                   Dislocated joint       Option A
# 38                                    Genetic factors       Option A
# 39                                Transverse fracture       Option D
# 40                                       Colon cancer       Option A
# 41                                           Leukemia       Option B
# 42                                        Skin cancer       Option A
# 43                                  Pancreatic cancer       Option B
# 44                                 Antibiotic therapy       Option D
# 45                                        Skin cancer       Option B
# 46                                       Brain cancer       Option D
# 47                                        Antibiotics       Option D
# 48                                  Pancreatic cancer       Option B
# 49                                            Surgery       Option C
#
#     difficulty_index  discriminatory_index
# 0           0.363213              0.551609
# 1           0.968528              0.377179
# 2           0.638722              0.840050
# 3           0.241212              0.236496
# 4           0.578842              0.464705
# 5           0.895648              0.189049
# 6           0.565823              0.796951
# 7           0.391468              0.377354
# 8           0.382524              0.584866
# 9           0.278733              0.544420
# 10          0.475518              0.228594
# 11          0.833595              0.456489
# 12          0.233315              0.182253
# 13          0.873816              0.138400
# 14          0.240237              0.710495
# 15          0.337222              0.364818
# 16          0.760231              0.282658
# 17          0.421329              0.731890
# 18          0.437306              0.162644
# 19          0.190690              0.815652
# 20          0.693739              0.741416
# 21          0.674983              0.137608
# 22          0.937474              0.237035
# 23          0.683245              0.196303
# 24          0.657577              0.272153
# 25          0.852703              0.944902
# 26          0.905985              0.574150
# 27          0.128423              0.244211
# 28          0.299533              0.431953
# 29          0.897705              0.368130
# 30          0.842426              0.667300
# 31          0.310408              0.998529
# 32          0.236365              0.449964
# 33          0.955573              0.694462
# 34          0.689753              0.921357
# 35          0.923917              0.218703
# 36          0.654275              0.950046
# 37          0.376962              0.510917
# 38          0.337248              0.476674
# 39          0.377544              0.780907
# 40          0.753796              0.545739
# 41          0.558212              0.716348
# 42          0.419508              0.268224
# 43          0.401118              0.898690
# 44          0.111371              0.178208
# 45          0.210922              0.588753
# 46          0.245593              0.449782
# 47          0.553783              0.877082
# 48          0.639566              0.349922
# 49          0.455351              0.162061

# %%
questions_list = all_questions_df.to_dict(orient='records')

# %%
import gurobipy as gp
from gurobipy import GRB
import ipywidgets as widgets
from IPython.display import display, clear_output
from functools import partial

class AdaptiveTest:
    def __init__(self, questions, total_questions=5):
        self.questions = questions
        self.total_questions = total_questions
        self.asked_questions = []
        self.correct_answers = 0
        self.correct_difficulty_indices = []
        self.current_difficulty = 0.5  # Starting difficulty index
        self.categories = list(set(q['category'] for q in questions))

    def adjust_difficulty(self, previous_difficulty, correct):
        if correct:
            return min(1.0, previous_difficulty + 0.1)
        else:
            return max(0.1, previous_difficulty - 0.1)

    def setup_milp_model(self, available_questions, category_counts):
        model = gp.Model("Question_Selection")
        
        # Variables: x[i] is 1 if question i is selected, 0 otherwise
        x = model.addVars(len(available_questions), vtype=GRB.BINARY, name="x")
        
        # Objective: Maximize the discriminatory index
        model.setObjective(gp.quicksum(available_questions[i]['discriminatory_index'] * x[i] for i in range(len(available_questions))), GRB.MAXIMIZE)
        
        # Constraints: Ensure 20% ± 5% category representation for the remaining questions
        remaining_questions = self.total_questions - len(self.asked_questions)
        for cat in self.categories:
            category_indices = [i for i in range(len(available_questions)) if available_questions[i]['category'] == cat]
            min_cat = max(0, 0.15 * remaining_questions - category_counts[cat])
            max_cat = min(len(category_indices), 0.25 * remaining_questions - category_counts[cat])
            model.addConstr(gp.quicksum(x[i] for i in category_indices) >= min_cat)
            model.addConstr(gp.quicksum(x[i] for i in category_indices) <= max_cat)
        
        # Ensure only one question is selected
        model.addConstr(gp.quicksum(x[i] for i in range(len(available_questions))) == 1)
        
        return model, x

    def get_next_question(self):
        available_questions = [q for q in self.questions if q['question_id'] not in self.asked_questions and 
                               abs(q['difficulty_index'] - self.current_difficulty) <= 0.2]

        if not available_questions:
            print("No more questions available with the current difficulty settings.")
            return None

        # Select a question ensuring 20% ± 5% category representation
        category_counts = {cat: 0 for cat in self.categories}
        for q_id in self.asked_questions:
            category_counts[self.questions[q_id]['category']] += 1

        model, x = self.setup_milp_model(available_questions, category_counts)
        model.optimize()
        
        selected_question_indices = [i for i in range(len(available_questions)) if x[i].x > 0.5]
        
        if not selected_question_indices:
            print("No feasible solution found by the MILP model. Relaxing constraints.")
            self.current_difficulty = self.adjust_difficulty(self.current_difficulty, False)
            return self.get_next_question()
        
        selected_question_index = selected_question_indices[0]
        selected_question = available_questions[selected_question_index]
        self.asked_questions.append(selected_question['question_id'])
        
        return selected_question

    def ask_question(self, question):
        clear_output(wait=True)  # Clear output before printing question
        print(f"Question: {question['question_id']}, Category: {question['category']}")  # Print the question
        option_buttons = []
        for idx, option in enumerate([question['options'][0], question['options'][1], question['options'][2], question['options'][3]]):
            button = widgets.Button(description=f"{chr(65+idx)}: {option}")
            button.on_click(partial(self.check_answer, question, chr(65+idx)))
            option_buttons.append(button)
            button.layout.width = 'auto'
            display(button)  # Display the options

    def check_answer(self, question, answer, b):
        correct_option_letter = chr(65 + question['correct_option'])  # Get the letter (A, B, C, or D)
        correct = (answer == correct_option_letter) 
        if correct:
            self.correct_answers += 1
            self.correct_difficulty_indices.append(question['difficulty_index'])
        
        self.current_difficulty = self.adjust_difficulty(self.current_difficulty, correct)
        
        if len(self.asked_questions) < self.total_questions:
            next_question = self.get_next_question()
            if next_question:
                self.ask_question(next_question)
            else:
                self.finish_test()
        else:
            self.finish_test()

    def finish_test(self):
        clear_output(wait=True)
        final_score = sum(self.correct_difficulty_indices)
        print(f"Test completed! You answered {self.correct_answers} out of {self.total_questions} questions correctly.")
        print(f"Your final score is: {final_score:.2f}")

    def start_test(self):
        self.correct_answers = 0
        self.asked_questions = []
        self.correct_difficulty_indices = []
        self.current_difficulty = 0.5  # Reset starting difficulty
        first_question = self.get_next_question()
        if first_question:
            self.ask_question(first_question)

# Example question list
questions_list = [{
    'question_id': i,
    'options': [f'Option {j+1}' for j in range(4)],
    'difficulty_index': np.random.uniform(0.1, 1.0),
    'discriminatory_index': np.random.uniform(0.1, 1.0),
    'category': np.random.choice(['Math', 'Science', 'History', 'Geography']),
    'correct_option': np.random.randint(0, 4)
} for i in range(1000)]

# Initialize the AdaptiveTest class with the questions
test = AdaptiveTest(questions_list)
test.start_test()
# Out:
# Gurobi Optimizer version 11.0.2 build v11.0.2rc0 (mac64[rosetta2] - Darwin 23.2.0 23C71)
#
# CPU model: Apple M1
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 9 rows, 428 columns and 1284 nonzeros
# Model fingerprint: 0x03b33130
# Variable types: 0 continuous, 428 integer (428 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e-01, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [8e-01, 1e+00]
# Presolve removed 0 rows and 424 columns
# Presolve time: 0.00s
#
# Explored 0 nodes (0 simplex iterations) in 0.01 seconds (0.00 work units)
# Thread count was 1 (of 8 available processors)
#
# Solution count 0
# No other solutions better than -1e+100
#
# Model is infeasible
# Best objective -, best bound -, gap -
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[23], line 131
#     129 # Initialize the AdaptiveTest class with the questions
#     130 test = AdaptiveTest(questions_list)
# --> 131 test.start_test()
#
# Cell In[23], line 115, in AdaptiveTest.start_test(self)
#     113 self.correct_difficulty_indices = []
#     114 self.current_difficulty = 0.5  # Reset starting difficulty
# --> 115 first_question = self.get_next_question()
#     116 if first_question:
#     117     self.ask_question(first_question)
#
# Cell In[23], line 62, in AdaptiveTest.get_next_question(self)
#      59 model, x = self.setup_milp_model(available_questions, category_counts)
#      60 model.optimize()
# ---> 62 selected_question_indices = [i for i in range(len(available_questions)) if x[i].x > 0.5]
#      64 if not selected_question_indices:
#      65     print("No feasible solution found by the MILP model. Relaxing constraints.")
#
# Cell In[23], line 62, in <listcomp>(.0)
#      59 model, x = self.setup_milp_model(available_questions, category_counts)
#      60 model.optimize()
# ---> 62 selected_question_indices = [i for i in range(len(available_questions)) if x[i].x > 0.5]
#      64 if not selected_question_indices:
#      65     print("No feasible solution found by the MILP model. Relaxing constraints.")
#
# File src/gurobipy/var.pxi:125, in gurobipy.Var.__getattr__()
#
# File src/gurobipy/var.pxi:153, in gurobipy.Var.getAttr()
#
# File src/gurobipy/attrutil.pxi:103, in gurobipy._getattr()
#
# AttributeError: Unable to retrieve attribute 'x'

# %%
import pulp
import ipywidgets as widgets
from IPython.display import display, clear_output
from functools import partial

class AdaptiveTest:
    def __init__(self, questions, total_questions=5):
        self.questions = questions
        self.total_questions = total_questions
        self.asked_questions = []
        self.correct_answers = 0
        self.correct_difficulty_indices = []
        self.current_difficulty = 0.5  # Starting difficulty index
        self.categories = list(set(q['Category'] for q in questions))

    def adjust_difficulty(self, previous_difficulty, correct):
        if correct:
            return min(1.0, previous_difficulty + 0.1)
        else:
            return max(0.1, previous_difficulty - 0.1)

    def setup_milp_model(self, available_questions, category_counts):
        model = pulp.LpProblem("Question_Selection", pulp.LpMaximize)
        x = pulp.LpVariable.dicts("x", range(len(available_questions)), cat="Binary")
        
        # Objective: Maximize the discriminatory index
        model += pulp.lpSum([available_questions[i]['discriminatory_index'] * x[i] for i in range(len(available_questions))])
        
        # Constraints: Ensure 20% ± 5% category representation for the remaining questions
        remaining_questions = self.total_questions - len(self.asked_questions)
        for cat in self.categories:
            category_indices = [i for i in range(len(available_questions)) if available_questions[i]['Category'] == cat]
            min_cat = max(0, 0.15 * remaining_questions - category_counts[cat])
            max_cat = min(len(category_indices), 0.25 * remaining_questions - category_counts[cat])
            #model += pulp.lpSum([x[i] for i in category_indices]) >= min_cat
            #model += pulp.lpSum([x[i] for i in category_indices]) <= max_cat
        
        # Ensure only one question is selected
        model += pulp.lpSum([x[i] for i in range(len(available_questions))]) == 1
        
        return model, x

    def get_next_question(self):
        available_questions = [q for q in self.questions if q['question_id'] not in self.asked_questions and 
                               abs(q['difficulty_index'] - self.current_difficulty) <= 0.2]

        if not available_questions:
            print("No more questions available with the current difficulty settings.")
            return None

        # Select a question ensuring 20% ± 5% category representation
        category_counts = {cat: 0 for cat in self.categories}
        for q_id in self.asked_questions:
            category_counts[self.questions[q_id]['Category']] += 1

        model, x = self.setup_milp_model(available_questions, category_counts)
        # **MISSING LINE:** Solve the MILP model
        model.solve() 
        
        selected_question_indices = [i for i in range(len(available_questions)) if pulp.value(x[i]) == 1]
        
        if not selected_question_indices:
            print("No feasible solution found by the MILP model. Relaxing constraints.")
            self.current_difficulty = self.adjust_difficulty(self.current_difficulty, False)
            return self.get_next_question()
        
        selected_question_index = selected_question_indices[0]
        selected_question = available_questions[selected_question_index]
        self.asked_questions.append(selected_question['question_id'])
        
        return selected_question

    def ask_question(self, question):
        clear_output(wait=True)  # Clear output before printing question
        print(f"Question: {question['Question']}, Category: {question['Category']}")  # Print the question
        option_buttons = []
        for idx, option in enumerate([question['Option A'], question['Option B'], question['Option C'], question['Option D']]):
            button = widgets.Button(description=f"{chr(65+idx)}: {option}")
            button.on_click(partial(self.check_answer, question, chr(65+idx)))
            option_buttons.append(button)
            button.layout.width = 'auto'
            display(button)  # Display the options

    def check_answer(self, question, answer, b):
        correct_option_letter = question['Correct Option'][-1]  # Get the last character (A, B, C, or D)
        correct = (answer == correct_option_letter) 
        if correct:
            self.correct_answers += 1
            self.correct_difficulty_indices.append(question['difficulty_index'])
        
        self.current_difficulty = self.adjust_difficulty(self.current_difficulty, correct)
        
        if len(self.asked_questions) < self.total_questions:
            next_question = self.get_next_question()
            if next_question:
                self.ask_question(next_question)
            else:
                self.finish_test()
        else:
            self.finish_test()

    def finish_test(self):
        clear_output(wait=True)
        final_score = sum(self.correct_difficulty_indices)
        print(f"Test completed! You answered {self.correct_answers} out of {self.total_questions} questions correctly.")
        print(f"Your final score is: {final_score:.2f}")

    def start_test(self):
        self.correct_answers = 0
        self.asked_questions = []
        self.correct_difficulty_indices = []
        self.current_difficulty = 0.5  # Reset starting difficulty
        first_question = self.get_next_question()
        if first_question:
            self.ask_question(first_question)

# Initialize the AdaptiveTest class with the questions
test = AdaptiveTest(questions_list)
test.start_test()
# Out:
# Test completed! You answered 4 out of 5 questions correctly.
# Your final score is: 2.21
