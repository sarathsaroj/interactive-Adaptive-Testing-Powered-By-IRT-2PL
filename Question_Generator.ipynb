# %% [markdown]
# ##### **This part of the project handles the question generation part. The project uses the OpenAI API functionality to make prompts and get questions based on the prompt given.**

# %%
import openai
from openai import OpenAI
import os
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings("ignore")
import random
from sentence_transformers import SentenceTransformer
from sentence_transformers import util

# %%
model = SentenceTransformer('all-mpnet-base-v2') 
os.environ["OPENAI_API_KEY"] = "sk-proj-fPbd82pXUd0snI5DTCSYT3BlbkFJNT1ZqfvGxFa1K1Pz3bJG"
def generate_questions(prompt, num_questions=10):
    
    try:
        
        ## Using OpenAI API, questions developed using prompting based on the requirement.
        api_key = os.getenv("OPENAI_API_KEY")
        if not api_key:
            raise ValueError("OPENAI_API_KEY environment variable not set.")

        client=OpenAI(api_key=api_key)
        generated_texts = set()
        generated_questions=[]
        questions = []
        i = 0

        while i < num_questions:
            variation_prompt = f"{prompt} - Question {i+1}"
            response = client.completions.create(
                model="gpt-3.5-turbo-instruct",
                prompt=f"I am in the process of developing a questionnaire with multiple choice questions to test general knowledge of Seniors in my University. I want diverse questions strictly"\
                    f" adhering to my required format. Generate a different multiple-choice question about {variation_prompt} strictly in the format:\n\n" \
                       f"Question:\n" \
                       f"Option A:\n" \
                       f"Option B:\n" \
                       f"Option C:\n" \
                       f"Option D:\n" \
                       f"Correct Option: Option A or Option B or Option C or Option D",
                max_tokens=250,
                n=1,
                stop=None,
                temperature=0.9
            )

            ## Question Format Check Filtering
            question_text=response.choices[0].text.strip()
            if question_text in generated_texts:
                continue

            generated_texts.add(question_text)
            lines = question_text.splitlines()
            lines = [line.strip() for line in lines if line.strip()]
            if len(lines) < 6:  # Check for the minimum expected length
                print("Error: OpenAI response is not formatted correctly.")
                continue
            if not (lines[0].startswith('Question:') and lines[1].startswith('Option A') and
                    lines[2].startswith('Option B') and lines[3].startswith('Option C') and
                    lines[4].startswith('Option D') and lines[5].startswith('Correct Option: Option')):
                continue
        
            ## This part ensures similar questions are not asked again (uses cosine similarity of the embeddings)
            is_duplicate= False
            for existing_question in generated_questions:
                question_embeddings = model.encode([lines[0], existing_question])
                cosine_similarity = util.cos_sim(question_embeddings[0], question_embeddings[1]).item()
                if cosine_similarity > 0.8: 
                    is_duplicate= True
                    print("Similar exitss")
                    break
            if is_duplicate:
                continue
            
            generated_questions.append(lines[0])


            ## Questions added to the list as a dictionary 
            question_data = {
                "Question": lines[0].replace("Question:", "").strip(),
                "Category": prompt,
                "Option A": lines[1].replace("Option A:", "").strip(),
                "Option B": lines[2].replace("Option B:", "").strip(),
                "Option C": lines[3].replace("Option C:", "").strip(),
                "Option D": lines[4].replace("Option D:", "").strip(),
                "Correct Option": lines[5].replace("Correct Option:", "").strip()[0:8]}

            questions.append(question_data)
            i += 1
            print(question_data)
        questions_df = pd.DataFrame(questions)
        return questions_df
    
    ## Error message output
    except ValueError as ve:
        print(f"ValueError: {ve}")
        return None
    except Exception as e:
        print(f"An error occurred: {e}")
        return None

# %%
## Prompts to generate questions (I have selected 5 GK categories )
prompts=["Sports", "Trivia", "International Affairs", "Science and Technology", "Historical Events"]
test_list =[generate_questions(prompt,num_questions=40) for prompt in prompts]
test=pd.concat(test_list,ignore_index=True)

## Creating unique question_id and storing as csv file
test=test.reset_index().rename(columns={'index':'question_id'})
prefix='Q'
test['question_id']=prefix+test['question_id'].astype(str)
test.to_csv('GK.csv',header=True)
# Out:
# {'Question': 'What year was the first modern Olympic Games held?', 'Category': 'Sports', 'Option A': '1912', 'Option B': '1896', 'Option C': '1908', 'Option D': '1924', 'Correct Option': 'Option B'}
# {'Question': 'Who is regarded as the greatest basketball player of all time?', 'Category': 'Sports', 'Option A': 'Michael Jordan', 'Option B': 'LeBron James', 'Option C': 'Kobe Bryant', 'Option D': 'Larry Bird', 'Correct Option': 'Option A'}
# {'Question': "Who holds the record for the most Grand Slam men's singles titles in tennis?", 'Category': 'Sports', 'Option A': 'Roger Federer', 'Option B': 'Rafael Nadal', 'Option C': 'Novak Djokovic', 'Option D': 'Andy Murray', 'Correct Option': 'Option A'}
# Similar exitss
# {'Question': 'Which former professional basketball player was known as "The Black Mamba"?', 'Category': 'Sports', 'Option A': 'Michael Jordan', 'Option B': 'Kobe Bryant', 'Option C': 'LeBron James', 'Option D': 'Larry Bird', 'Correct Option': 'Option B'}
# {'Question': 'In what year did the United States host the Winter Olympic Games for the first time?', 'Category': 'Sports', 'Option A': '1960', 'Option B': '1972', 'Option C': '1980', 'Option D': '1996', 'Correct Option': 'Option C'}
# {'Question': 'Which country won the 2018 FIFA World Cup?', 'Category': 'Sports', 'Option A': 'Brazil', 'Option B': 'France', 'Option C': 'Germany', 'Option D': 'Argentina', 'Correct Option': 'Option B'}
# {'Question': 'Who holds the record for the most Olympic gold medals in swimming?', 'Category': 'Sports', 'Option A': 'Michael Phelps', 'Option B': 'Usain Bolt', 'Option C': 'Simone Biles', 'Option D': 'Serena Williams', 'Correct Option': 'Option A'}
# Similar exitss
# Similar exitss
# {'Question': 'Which country holds the record for the most Olympic gold medals in basketball?', 'Category': 'Sports', 'Option A': 'United States', 'Option B': 'China', 'Option C': 'Russia', 'Option D': 'Australia', 'Correct Option': 'Option A'}
# Similar exitss
# Similar exitss
# {'Question': "Which country has the most Olympic gold medals in women's figure skating?", 'Category': 'Sports', 'Option A': 'Canada', 'Option B': 'United States', 'Option C': 'Russia', 'Option D': 'Japan', 'Correct Option': 'Option B'}
# {'Question': 'Who is considered the "GOAT" (Greatest of All Time) in Tennis?', 'Category': 'Sports', 'Option A': 'Serena Williams', 'Option B': 'Roger Federer', 'Option C': 'Rafael Nadal', 'Option D': 'Novak Djokovic', 'Correct Option': 'Option B'}
# Similar exitss
# {'Question': 'Who is known as the "King of Clay" in the sport of tennis?', 'Category': 'Sports', 'Option A': 'Roger Federer', 'Option B': 'Novak Djokovic', 'Option C': 'Rafael Nadal', 'Option D': 'Andy Murray', 'Correct Option': 'Option C'}
# {'Question': 'Who is the only athlete to win Olympic gold in both the summer and winter games?', 'Category': 'Sports', 'Option A': 'Michael Phelps', 'Option B': 'Usain Bolt', 'Option C': 'Simone Biles', 'Option D': 'Eddie Eagan', 'Correct Option': 'Option D'}
# {'Question': 'Who is the all-time leading scorer in NBA history?', 'Category': 'Sports', 'Option A': 'Michael Jordan', 'Option B': 'LeBron James', 'Option C': 'Kobe Bryant', 'Option D': 'Kareem Abdul-Jabbar', 'Correct Option': 'Option D'}
# Similar exitss
# {'Question': 'What is the nickname of the National Basketball Association team based in Boston?', 'Category': 'Sports', 'Option A': 'Celtics', 'Option B': 'Lakers', 'Option C': 'Bulls', 'Option D': 'Warriors', 'Correct Option': 'Option A'}
# {'Question': 'What is the official ball used in a game of soccer?', 'Category': 'Sports', 'Option A': 'Football', 'Option B': 'Baseball', 'Option C': 'Basketball', 'Option D': 'Soccer ball', 'Correct Option': 'Option D'}
# Similar exitss
# {'Question': 'How many players are on the field for a regulation game of American football?', 'Category': 'Sports', 'Option A': '9', 'Option B': '11', 'Option C': '13', 'Option D': '15', 'Correct Option': 'Option B'}
# {'Question': 'Which of the following countries has won the most FIFA World Cup titles?', 'Category': 'Sports', 'Option A': 'Brazil', 'Option B': 'Germany', 'Option C': 'Argentina', 'Option D': 'Italy', 'Correct Option': 'Option A'}
# {'Question': "Which team won the first ever FIFA Women's World Cup in 1991?", 'Category': 'Sports', 'Option A': 'United States', 'Option B': 'Brazil', 'Option C': 'Japan', 'Option D': 'Germany', 'Correct Option': 'Option A'}
# Similar exitss
# {'Question': 'Who is the only athlete to win the Olympic Gold Medal in both the 100-meter and 200-meter dash three times in a row?', 'Category': 'Sports', 'Option A': 'Usain Bolt', 'Option B': 'Jesse Owens', 'Option C': 'Carl Lewis', 'Option D': 'Michael Johnson', 'Correct Option': 'Option A'}
# {'Question': 'Who was the first African American to win an Olympic gold medal in an individual event?', 'Category': 'Sports', 'Option A': 'Jesse Owens', 'Option B': 'Wilma Rudolph', 'Option C': 'Jackie Joyner-Kersee', 'Option D': 'Usain Bolt', 'Correct Option': 'Option A'}
# Similar exitss
# Similar exitss
# Similar exitss
# Similar exitss
# {'Question': "Who won the 2019 World Cup in men's cricket?", 'Category': 'Sports', 'Option A': 'England', 'Option B': 'India', 'Option C': 'Australia', 'Option D': 'New Zealand', 'Correct Option': 'Option A'}
# {'Question': "Who won the 2019 FIFA Women's World Cup?", 'Category': 'Sports', 'Option A': 'United States', 'Option B': 'Brazil', 'Option C': 'Germany', 'Option D': 'France', 'Correct Option': 'Option A'}
# Similar exitss
# Similar exitss
# Similar exitss
# {'Question': "Who is the current #1 ranked men's tennis player in the world according to the ATP rankings?", 'Category': 'Sports', 'Option A': 'Rafael Nadal', 'Option B': 'Novak Djokovic', 'Option C': 'Roger Federer', 'Option D': 'Andy Murray', 'Correct Option': 'Option B'}
# Similar exitss
# Similar exitss
# Similar exitss
# Similar exitss
# {'Question': 'Who was the first female athlete to appear on the cover of Sports Illustrated magazine?', 'Category': 'Sports', 'Option A': 'Serena Williams', 'Option B': 'Steffi Graf', 'Option C': 'Billie Jean King', 'Option D': 'Simone Biles', 'Correct Option': 'Option C'}
# {'Question': 'Which of the following sports is not an Olympic sport?', 'Category': 'Sports', 'Option A': 'Basketball', 'Option B': 'Swimming', 'Option C': 'Curling', 'Option D': 'Rugby', 'Correct Option': 'Option D'}
# {'Question': 'Who is known as the "Queen of the Court" in the sport of tennis?', 'Category': 'Sports', 'Option A': 'Serena Williams', 'Option B': 'Maria Sharapova', 'Option C': 'Simona Halep', 'Option D': 'Naomi Osaka', 'Correct Option': 'Option A'}
# {'Question': 'In which year did Usain Bolt set the world record for the 100-meter dash?', 'Category': 'Sports', 'Option A': '2008', 'Option B': '2012', 'Option C': '2016', 'Option D': '2020', 'Correct Option': 'Option A'}
# {'Question': "Who is the current captain of the US Women's National Soccer Team?", 'Category': 'Sports', 'Option A': 'Megan Rapinoe', 'Option B': 'Alex Morgan', 'Option C': 'Carli Lloyd', 'Option D': 'Julie Ertz', 'Correct Option': 'Option A'}
# {'Question': 'Which team has won the most Super Bowls in NFL history?', 'Category': 'Sports', 'Option A': 'Dallas Cowboys', 'Option B': 'New England Patriots', 'Option C': 'Pittsburgh Steelers', 'Option D': 'Green Bay Packers', 'Correct Option': 'Option C'}
# Similar exitss
# {'Question': 'Who was the first female athlete to run a sub-four minute mile?', 'Category': 'Sports', 'Option A': 'Wilma Rudolph', 'Option B': 'Florence Griffith Joyner', 'Option C': 'Jackie Joyner-Kersee', 'Option D': 'Diane Leather-Roberts', 'Correct Option': 'Option D'}
# Error: OpenAI response is not formatted correctly.
# {'Question': 'Which sport is often referred to as "the sport of kings"?', 'Category': 'Sports', 'Option A': 'Polo', 'Option B': 'Football', 'Option C': 'Basketball', 'Option D': 'Tennis', 'Correct Option': 'Option A'}
# {'Question': 'Who holds the record for most career home runs in MLB history?', 'Category': 'Sports', 'Option A': 'Babe Ruth', 'Option B': 'Barry Bonds', 'Option C': 'Hank Aaron', 'Option D': 'Ken Griffey Jr.', 'Correct Option': 'Option C'}
# {'Question': 'Who was the first female athlete to win an Olympic gold medal in gymnastics?', 'Category': 'Sports', 'Option A': 'Nadia Comaneci', 'Option B': 'Mary Lou Retton', 'Option C': 'Simone Biles', 'Option D': 'Gabby Douglas', 'Correct Option': 'Option A'}
# Similar exitss
# Similar exitss
# Similar exitss
# {'Question': 'Which professional football team won the Super Bowl in 2020?', 'Category': 'Sports', 'Option A': 'Kansas City Chiefs', 'Option B': 'San Francisco 49ers', 'Option C': 'New England Patriots', 'Option D': 'Seattle Seahawks', 'Correct Option': 'Option A'}
# Similar exitss
# {'Question': 'In what year did the Olympics include skiing as an official event?', 'Category': 'Sports', 'Option A': '1924', 'Option B': '1936', 'Option C': '1952', 'Option D': '1968', 'Correct Option': 'Option B'}
# Similar exitss
# Similar exitss
# {'Question': 'In which sport is the term "grand slam" used to describe winning all four major tournaments in a single year?', 'Category': 'Sports', 'Option A': 'Tennis', 'Option B': 'Soccer', 'Option C': 'Golf', 'Option D': 'Swimming', 'Correct Option': 'Option A'}
# Similar exitss
# Similar exitss
# Similar exitss
# {'Question': 'Which city hosted the 2016 Summer Olympics?', 'Category': 'Sports', 'Option A': 'Rio de Janeiro, Brazil', 'Option B': 'Beijing, China', 'Option C': 'Tokyo, Japan', 'Option D': 'Sydney, Australia', 'Correct Option': 'Option A'}
# Similar exitss
# {'Question': 'Which of the following countries won the most medals in the 2020 Summer Olympics?', 'Category': 'Sports', 'Option A': 'United States', 'Option B': 'China', 'Option C': 'Japan', 'Option D': 'Australia', 'Correct Option': 'Option B'}
# Similar exitss
# Similar exitss
# Similar exitss
# Similar exitss
# {'Question': 'In what year did Serena Williams become the first tennis player to win all four Grand Slam titles in a single season?', 'Category': 'Sports', 'Option A': '2011', 'Option B': '2014', 'Option C': '2015', 'Option D': '2017', 'Correct Option': 'Option C'}
# {'Question': 'Who won the first ever FIFA World Cup in 1930?', 'Category': 'Sports', 'Option A': 'Uruguay', 'Option B': 'Brazil', 'Option C': 'Italy', 'Option D': 'Germany', 'Correct Option': 'Option A'}
# {'Question': 'Who was the first female Prime Minister in the world?', 'Category': 'Trivia', 'Option A': 'Margaret Thatcher', 'Option B': 'Indira Gandhi', 'Option C': 'Golda Meir', 'Option D': 'Sirimavo Bandaranaike', 'Correct Option': 'Option B'}
# {'Question': 'Which famous landmark is located in Paris, France?', 'Category': 'Trivia', 'Option A': 'Eiffel Tower', 'Option B': 'Statue of Liberty', 'Option C': 'Big Ben', 'Option D': 'Taj Mahal', 'Correct Option': 'Option A'}
# {'Question': 'Which American singer is known for her hit song "Single Ladies (Put a Ring on It)"?', 'Category': 'Trivia', 'Option A': 'Beyoncé', 'Option B': 'Adele', 'Option C': 'Taylor Swift', 'Option D': 'Lady Gaga', 'Correct Option': 'Option A'}
# Similar exitss
# Similar exitss
# {'Question': 'Who was the first female pilot to fly solo across the Atlantic Ocean?', 'Category': 'Trivia', 'Option A': 'Amelia Earhart', 'Option B': 'Bessie Coleman', 'Option C': 'Katherine Stinson', 'Option D': 'Harriet Quimby', 'Correct Option': 'Option A'}
# {'Question': 'In what year did the first color television become available for purchase in the United States?', 'Category': 'Trivia', 'Option A': '1951', 'Option B': '1954', 'Option C': '1965', 'Option D': '1972', 'Correct Option': 'Option B'}
# Similar exitss
# {'Question': 'Who sang the song "Bohemian Rhapsody"?', 'Category': 'Trivia', 'Option A': 'Queen', 'Option B': 'The Beatles', 'Option C': 'Michael Jackson', 'Option D': 'Elvis Presley', 'Correct Option': 'Option A'}
# Similar exitss
# {'Question': 'What is the largest mammal in the world based on weight?', 'Category': 'Trivia', 'Option A': 'African elephant', 'Option B': 'Blue whale', 'Option C': 'Polar bear', 'Option D': 'Hippopotamus', 'Correct Option': 'Option B'}
# {'Question': 'What is the name of the famous scientist who developed the theory of relativity?', 'Category': 'Trivia', 'Option A': 'Sir Isaac Newton', 'Option B': 'Galileo Galilei', 'Option C': 'Albert Einstein', 'Option D': 'Charles Darwin', 'Correct Option': 'Option C'}
# {'Question': 'Who was the first female astronaut to travel to space?', 'Category': 'Trivia', 'Option A': 'Sally Ride', 'Option B': 'Mae Jemison', 'Option C': 'Valentina Tereshkova', 'Option D': 'Judith Resnik', 'Correct Option': 'Option C'}
# {'Question': 'In Greek mythology, who was the god of music?', 'Category': 'Trivia', 'Option A': 'Apollo', 'Option B': 'Zeus', 'Option C': 'Ares', 'Option D': 'Hermes', 'Correct Option': 'Option A'}
# {'Question': 'Which US state is known as the "Sunshine State"?', 'Category': 'Trivia', 'Option A': 'Florida', 'Option B': 'California', 'Option C': 'Texas', 'Option D': 'Hawaii', 'Correct Option': 'Option A'}
# {'Question': 'What does the acronym "NASA" stand for?', 'Category': 'Trivia', 'Option A': 'National Aeronautics and Space Administration', 'Option B': 'National Association of Space Agencies', 'Option C': 'National Aerospace and Space Alliance', 'Option D': 'North American Space Authority', 'Correct Option': 'Option A'}
# Similar exitss
# {'Question': 'Who is the creator of the famous painting "Starry Night"?', 'Category': 'Trivia', 'Option A': 'Leonardo da Vinci', 'Option B': 'Claude Monet', 'Option C': 'Vincent van Gogh', 'Option D': 'Pablo Picasso', 'Correct Option': 'Option C'}
# {'Question': 'Who was the first woman to win a Nobel Prize?', 'Category': 'Trivia', 'Option A': 'Marie Curie', 'Option B': 'Mother Teresa', 'Option C': 'Malala Yousafzai', 'Option D': 'Margaret Thatcher', 'Correct Option': 'Option A'}
# {'Question': 'What is the largest planet in our solar system by volume?', 'Category': 'Trivia', 'Option A': 'Mars', 'Option B': 'Jupiter', 'Option C': 'Earth', 'Option D': 'Saturn', 'Correct Option': 'Option B'}
# {'Question': 'What is the capital of Australia?', 'Category': 'Trivia', 'Option A': 'Sydney', 'Option B': 'Melbourne', 'Option C': 'Brisbane', 'Option D': 'Canberra', 'Correct Option': 'Option D'}
# {'Question': 'In which year did the first man walk on the moon?', 'Category': 'Trivia', 'Option A': '1969', 'Option B': '1972', 'Option C': '1985', 'Option D': '1999', 'Correct Option': 'Option A'}
# {'Question': 'Which of the following singers released the hit song "Thriller" in 1982?', 'Category': 'Trivia', 'Option A': 'Billy Joel', 'Option B': 'Madonna', 'Option C': 'Michael Jackson', 'Option D': 'Prince', 'Correct Option': 'Option C'}
# {'Question': 'What is the name of the famous Egyptian pharaoh who built the Great Pyramid of Giza?', 'Category': 'Trivia', 'Option A': 'Ramses II', 'Option B': 'Tutankhamun', 'Option C': 'Cleopatra', 'Option D': 'Khufu', 'Correct Option': 'Option D'}
# {'Question': 'How many players are on a standard soccer team?', 'Category': 'Trivia', 'Option A': '9', 'Option B': '11', 'Option C': '13', 'Option D': '15', 'Correct Option': 'Option B'}
# {'Question': 'What is the capital city of Canada?', 'Category': 'Trivia', 'Option A': 'Toronto', 'Option B': 'Ottawa', 'Option C': 'Montreal', 'Option D': 'Vancouver', 'Correct Option': 'Option B'}
# Similar exitss
# {'Question': 'Which of the following animals is not a mammal?', 'Category': 'Trivia', 'Option A': 'Elephant', 'Option B': 'Dolphin', 'Option C': 'Snake', 'Option D': 'Gorilla', 'Correct Option': 'Option C'}
# Similar exitss
# {'Question': 'Which country is home to the mysterious Stonehenge monument?', 'Category': 'Trivia', 'Option A': 'Italy', 'Option B': 'Egypt', 'Option C': 'United States', 'Option D': 'United Kingdom', 'Correct Option': 'Option D'}
# Similar exitss
# {'Question': 'Which of these planets is known for its iconic rings?', 'Category': 'Trivia', 'Option A': 'Saturn', 'Option B': 'Mars', 'Option C': 'Jupiter', 'Option D': 'Venus', 'Correct Option': 'Option A'}
# Similar exitss
# {'Question': 'Which country has the longest coastline in the world?', 'Category': 'Trivia', 'Option A': 'Canada', 'Option B': 'Australia', 'Option C': 'United States', 'Option D': 'Russia', 'Correct Option': 'Option A'}
# {'Question': 'Which famous singer famously performed the national anthem at the Super Bowl in 1991?', 'Category': 'Trivia', 'Option A': 'Whitney Houston', 'Option B': 'Mariah Carey', 'Option C': 'Beyoncé', 'Option D': 'Aretha Franklin', 'Correct Option': 'Option A'}
# {'Question': 'What is the capital of Brazil?', 'Category': 'Trivia', 'Option A': 'Rio de Janeiro', 'Option B': 'Brasilia', 'Option C': 'Sao Paulo', 'Option D': 'Salvador', 'Correct Option': 'Option B'}
# {'Question': 'What is the national flower of Japan?', 'Category': 'Trivia', 'Option A': 'Cherry Blossom', 'Option B': 'Lotus', 'Option C': 'Sunflower', 'Option D': 'Rose', 'Correct Option': 'Option A'}
# {'Question': 'What famous artist painted the Mona Lisa?', 'Category': 'Trivia', 'Option A': 'Vincent van Gogh', 'Option B': 'Pablo Picasso', 'Option C': 'Leonardo da Vinci', 'Option D': 'Michelangelo', 'Correct Option': 'Option C'}
# Similar exitss
# {'Question': 'What year did the Titanic sink?', 'Category': 'Trivia', 'Option A': '1912', 'Option B': '1914', 'Option C': '1920', 'Option D': '1924', 'Correct Option': 'Option A'}
# {'Question': 'What is the most widely spoken language in the world?', 'Category': 'Trivia', 'Option A': 'Mandarin Chinese', 'Option B': 'English', 'Option C': 'Spanish', 'Option D': 'Hindi', 'Correct Option': 'Option A'}
# Similar exitss
# {'Question': 'In what year did the first iPhone model release?', 'Category': 'Trivia', 'Option A': '2005', 'Option B': '2007', 'Option C': '2010', 'Option D': '2013', 'Correct Option': 'Option B'}
# {'Question': 'In Greek mythology, who is the god of wine and parties?', 'Category': 'Trivia', 'Option A': 'Zeus', 'Option B': 'Apollo', 'Option C': 'Dionysus', 'Option D': 'Hades', 'Correct Option': 'Option C'}
# Similar exitss
# Similar exitss
# Similar exitss
# Similar exitss
# {'Question': 'What type of animal is known for its ability to change colors based on its surroundings?', 'Category': 'Trivia', 'Option A': 'Chameleon', 'Option B': 'Zebra', 'Option C': 'Giraffe', 'Option D': 'Kangaroo', 'Correct Option': 'Option A'}
# Similar exitss
# {'Question': 'Which iconic fashion designer famously said, "In order to be irreplaceable, one must always be different"?', 'Category': 'Trivia', 'Option A': 'Coco Chanel', 'Option B': 'Giorgio Armani', 'Option C': 'Calvin Klein', 'Option D': 'Ralph Lauren', 'Correct Option': 'Option A'}
# Similar exitss
# {'Question': 'Which actress won the Best Actress Academy Award for her role in the film "Monster\'s Ball"?', 'Category': 'Trivia', 'Option A': 'Halle Berry', 'Option B': 'Meryl Streep', 'Option C': 'Julia Roberts', 'Option D': 'Nicole Kidman', 'Correct Option': 'Option A'}
# Similar exitss
# {'Question': 'Who is known as the "Father of Geometry"?', 'Category': 'Trivia', 'Option A': 'Albert Einstein', 'Option B': 'Euclid', 'Option C': 'Pythagoras', 'Option D': 'Isaac Newton', 'Correct Option': 'Option B'}
# {'Question': 'Which renowned scientist is credited with the development of the three laws of motion?', 'Category': 'Trivia', 'Option A': 'Isaac Newton', 'Option B': 'Albert Einstein', 'Option C': 'Galileo Galilei', 'Option D': 'Marie Curie', 'Correct Option': 'Option A'}
# {'Question': 'What is the name of the longest river in South America?', 'Category': 'Trivia', 'Option A': 'Amazon River', 'Option B': 'Nile River', 'Option C': 'Volga River', 'Option D': 'Mississippi River', 'Correct Option': 'Option A'}
# {'Question': 'Which city is known as the "Windy City"?', 'Category': 'Trivia', 'Option A': 'Chicago', 'Option B': 'New York City', 'Option C': 'Los Angeles', 'Option D': 'Miami', 'Correct Option': 'Option A'}
# {'Question': 'Which international organization is responsible for maintaining peace and security among its member countries?', 'Category': 'International Affairs', 'Option A': 'United Nations', 'Option B': 'European Union', 'Option C': 'World Trade Organization', 'Option D': 'International Criminal Court', 'Correct Option': 'Option A'}
# {'Question': 'Which country is known for having the longest continuous wall built by humans?', 'Category': 'International Affairs', 'Option A': 'China', 'Option B': 'India', 'Option C': 'Egypt', 'Option D': 'Italy', 'Correct Option': 'Option A'}
# {'Question': 'What is the official currency of Japan?', 'Category': 'International Affairs', 'Option A': 'Yen', 'Option B': 'Euro', 'Option C': 'Dollar', 'Option D': 'Yuan', 'Correct Option': 'Option A'}
# {'Question': 'What is the capital city of Canada?', 'Category': 'International Affairs', 'Option A': 'Ottawa', 'Option B': 'Toronto', 'Option C': 'Montreal', 'Option D': 'Vancouver', 'Correct Option': 'Option A'}
# {'Question': 'What was the subject of the negotiations between North Korea and the United States in 2018?', 'Category': 'International Affairs', 'Option A': 'Nuclear weapons', 'Option B': 'Trade agreements', 'Option C': 'Human rights violations', 'Option D': 'Environmental protection', 'Correct Option': 'Option A'}
# {'Question': 'Which country is not a permanent member of the United Nations Security Council?', 'Category': 'International Affairs', 'Option A': 'China', 'Option B': 'France', 'Option C': 'India', 'Option D': 'Germany', 'Correct Option': 'Option C'}
# {'Question': "Which country is the largest contributor to the United Nations' regular budget?", 'Category': 'International Affairs', 'Option A': 'United States', 'Option B': 'China', 'Option C': 'Germany', 'Option D': 'Japan', 'Correct Option': 'Option A'}
# {'Question': 'In which year did the United Nations officially recognize the State of Palestine as a non-member observer state?', 'Category': 'International Affairs', 'Option A': '1948', 'Option B': '1993', 'Option C': '2005', 'Option D': '2012', 'Correct Option': 'Option D'}
# Similar exitss
# Error: OpenAI response is not formatted correctly.
# {'Question': 'Which country is known as the "Land of the Rising Sun"?', 'Category': 'International Affairs', 'Option A': 'China', 'Option B': 'Japan', 'Option C': 'South Korea', 'Option D': 'Thailand', 'Correct Option': 'Option B'}
# Similar exitss
# Similar exitss
# Similar exitss
# Similar exitss
# Similar exitss
# Similar exitss
# Similar exitss
# Similar exitss
# {'Question': 'What is the name of the international organization that aims to promote economic stability and cooperation among its member countries?', 'Category': 'International Affairs', 'Option A': 'United Nations', 'Option B': 'World Bank', 'Option C': 'International Monetary Fund', 'Option D': 'International Red Cross', 'Correct Option': 'Option C'}
# Similar exitss
# Similar exitss
# Similar exitss
# Similar exitss
# Similar exitss
# Similar exitss
# Similar exitss
# {'Question': 'Which country is part of the "Five Eyes" intelligence alliance?', 'Category': 'International Affairs', 'Option A': 'France', 'Option B': 'Japan', 'Option C': 'United Kingdom', 'Option D': 'China', 'Correct Option': 'Option C'}
# Similar exitss
# Similar exitss
# Similar exitss
# {'Question': 'Which country is not a member of the G7 group of nations?', 'Category': 'International Affairs', 'Option A': 'Japan', 'Option B': 'Russia', 'Option C': 'Canada', 'Option D': 'France', 'Correct Option': 'Option B'}
# Similar exitss
# Similar exitss
# {'Question': 'Which country is considered to be the largest economy in Africa?', 'Category': 'International Affairs', 'Option A': 'Egypt', 'Option B': 'South Africa', 'Option C': 'Nigeria', 'Option D': 'Morocco', 'Correct Option': 'Option C'}
# Similar exitss
# {'Question': 'Which country has the largest economy in the world based on GDP in 2020?', 'Category': 'International Affairs', 'Option A': 'United Kingdom', 'Option B': 'China', 'Option C': 'Germany', 'Option D': 'United States', 'Correct Option': 'Option D'}
# Similar exitss
# Similar exitss
# {'Question': 'In which country is the headquarters of the United Nations located?', 'Category': 'International Affairs', 'Option A': 'Switzerland', 'Option B': 'United Kingdom', 'Option C': 'United States', 'Option D': 'France', 'Correct Option': 'Option C'}
# Similar exitss
# {'Question': 'What organization was formed in 1945 to promote international cooperation and maintain peace and security among nations?', 'Category': 'International Affairs', 'Option A': 'United Nations', 'Option B': 'European Union', 'Option C': 'International Red Cross', 'Option D': 'World Health Organization', 'Correct Option': 'Option A'}
# Similar exitss
# Similar exitss
# {'Question': 'Who is the current Secretary-General of the United Nations?', 'Category': 'International Affairs', 'Option A': 'Ban Ki-moon', 'Option B': 'António Guterres', 'Option C': 'Kofi Annan', 'Option D': 'Jacques Delors', 'Correct Option': 'Option B'}
# Similar exitss
# Similar exitss
# Similar exitss
# Similar exitss
# {'Question': 'Which country is currently facing economic sanctions due to its nuclear program?', 'Category': 'International Affairs', 'Option A': 'Iran', 'Option B': 'North Korea', 'Option C': 'Venezuela', 'Option D': 'Cuba', 'Correct Option': 'Option B'}
# Similar exitss
# Similar exitss
# Similar exitss
# Similar exitss
# Similar exitss
# Similar exitss
# Similar exitss
# Error: OpenAI response is not formatted correctly.
# {'Question': 'Which country is currently hosting the 2020 Summer Olympics?', 'Category': 'International Affairs', 'Option A': 'Japan', 'Option B': 'Brazil', 'Option C': 'United States', 'Option D': 'South Korea', 'Correct Option': 'Option A'}
# {'Question': 'Which country is currently facing economic sanctions for its involvement in the conflict in Ukraine?', 'Category': 'International Affairs', 'Option A': 'Russia', 'Option B': 'China', 'Option C': 'United Kingdom', 'Option D': 'Brazil', 'Correct Option': 'Option A'}
# {'Question': 'In what year was the United Nations officially formed?', 'Category': 'International Affairs', 'Option A': '1945', 'Option B': '1955', 'Option C': '1965', 'Option D': '1975', 'Correct Option': 'Option A'}
# {'Question': 'Who was the first female Prime Minister of the United Kingdom?', 'Category': 'International Affairs', 'Option A': 'Angela Merkel', 'Option B': 'Theresa May', 'Option C': 'Margaret Thatcher', 'Option D': 'Jacinda Ardern', 'Correct Option': 'Option C'}
# Similar exitss
# Similar exitss
# {'Question': 'In which country is the International Criminal Court (ICC) headquartered?', 'Category': 'International Affairs', 'Option A': 'France', 'Option B': 'Germany', 'Option C': 'Netherlands', 'Option D': 'United Kingdom', 'Correct Option': 'Option C'}
# {'Question': 'What is the capital city of Brazil?', 'Category': 'International Affairs', 'Option A': 'Rio de Janeiro', 'Option B': 'Brasilia', 'Option C': 'Salvador', 'Option D': 'São Paulo', 'Correct Option': 'Option B'}
# Similar exitss
# Similar exitss
# Similar exitss
# Similar exitss
# Similar exitss
# {'Question': 'NATO is an international military alliance formed after World War II. What does NATO stand for?', 'Category': 'International Affairs', 'Option A': 'North African Treaty Organization', 'Option B': 'Nordic Atlantic Treaty Organization', 'Option C': 'North American Trade Organization', 'Option D': 'North Atlantic Treaty Organization', 'Correct Option': 'Option D'}
# Similar exitss
# Similar exitss
# {'Question': 'What is the capital of Japan?', 'Category': 'International Affairs', 'Option A': 'Tokyo', 'Option B': 'Beijing', 'Option C': 'Seoul', 'Option D': 'Singapore', 'Correct Option': 'Option A'}
# Similar exitss
# Similar exitss
# {'Question': 'Which treaty established the European Union (EU)?', 'Category': 'International Affairs', 'Option A': 'Treaty of Rome', 'Option B': 'Treaty of Versailles', 'Option C': 'Treaty of Lisbon', 'Option D': 'Treaty of Maastricht', 'Correct Option': 'Option D'}
# Similar exitss
# Similar exitss
# Similar exitss
# {'Question': 'Who won the Nobel Peace Prize in 2020 for his efforts in international diplomacy and resolving conflicts?', 'Category': 'International Affairs', 'Option A': 'Imran Khan', 'Option B': 'Donald Trump', 'Option C': 'Justin Trudeau', 'Option D': 'Abiy Ahmed', 'Correct Option': 'Option D'}
# Similar exitss
# Similar exitss
# Similar exitss
# Similar exitss
# Similar exitss
# Similar exitss
# {'Question': 'In which year did the United Nations officially adopt the Universal Declaration of Human Rights?', 'Category': 'International Affairs', 'Option A': '1948', 'Option B': '1954', 'Option C': '1962', 'Option D': '1972', 'Correct Option': 'Option A'}
# {'Question': 'In which country did the Arab Spring uprising first begin in 2010?', 'Category': 'International Affairs', 'Option A': 'Egypt', 'Option B': 'Tunisia', 'Option C': 'Yemen', 'Option D': 'Bahrain', 'Correct Option': 'Option B'}
# Similar exitss
# {'Question': 'In which year did the United Nations officially adopt the Sustainable Development Goals (SDGs)?', 'Category': 'International Affairs', 'Option A': '2015', 'Option B': '2010', 'Option C': '2005', 'Option D': '2020', 'Correct Option': 'Option A'}
# Similar exitss
# Similar exitss
# Similar exitss
# Similar exitss
# {'Question': 'Which country will host the 2022 FIFA World Cup?', 'Category': 'International Affairs', 'Option A': 'Qatar', 'Option B': 'United States', 'Option C': 'Japan', 'Option D': 'Brazil', 'Correct Option': 'Option A'}
# {'Question': 'Which country is not a member of the European Union?', 'Category': 'International Affairs', 'Option A': 'Switzerland', 'Option B': 'France', 'Option C': 'Germany', 'Option D': 'United Kingdom', 'Correct Option': 'Option A'}
# Similar exitss
# Similar exitss
# Similar exitss
# Similar exitss
# {'Question': 'Which country currently holds the rotating presidency of the United Nations Security Council for the month of September 2021?', 'Category': 'International Affairs', 'Option A': 'China', 'Option B': 'United States', 'Option C': 'United Kingdom', 'Option D': 'France', 'Correct Option': 'Option C'}
# Similar exitss
# Similar exitss
# Similar exitss
# Similar exitss
# Similar exitss
# Similar exitss
# Similar exitss
# Error: OpenAI response is not formatted correctly.
# Similar exitss
# Similar exitss
# {'Question': 'Which country is currently experiencing the longest ongoing civil war in the world?', 'Category': 'International Affairs', 'Option A': 'Sudan', 'Option B': 'Syria', 'Option C': 'Yemen', 'Option D': 'Afghanistan', 'Correct Option': 'Option A'}
# Similar exitss
# {'Question': 'What is the capital of South Korea?', 'Category': 'International Affairs', 'Option A': 'Beijing', 'Option B': 'Tokyo', 'Option C': 'Seoul', 'Option D': 'Bangkok', 'Correct Option': 'Option C'}
# Similar exitss
# Similar exitss
# Similar exitss
# {'Question': 'In which year did the United Kingdom officially leave the European Union (EU)?', 'Category': 'International Affairs', 'Option A': '2016', 'Option B': '2017', 'Option C': '2018', 'Option D': '2019', 'Correct Option': 'Option D'}
# {'Question': 'Which organization was formed as a result of the Bretton Woods Conference in 1944 to promote international trade and economic cooperation among member countries?', 'Category': 'International Affairs', 'Option A': 'United Nations', 'Option B': 'World Trade Organization', 'Option C': 'International Monetary Fund', 'Option D': 'European Union', 'Correct Option': 'Option C'}
# {'Question': 'Who was the first woman to serve as the United Nations Secretary-General?', 'Category': 'International Affairs', 'Option A': 'Madeleine Albright', 'Option B': 'Kofi Annan', 'Option C': 'Ban Ki-moon', 'Option D': 'Dag Hammarskjöld', 'Correct Option': 'Option B'}
# Similar exitss
# {'Question': 'Which country was the first to legalize same-sex marriage?', 'Category': 'International Affairs', 'Option A': 'Canada', 'Option B': 'United States', 'Option C': 'Australia', 'Option D': 'Germany', 'Correct Option': 'Option A'}
# {'Question': 'What is the maximum number of electrons that can occupy a single orbital?', 'Category': 'Science and Technology', 'Option A': '4', 'Option B': '2', 'Option C': '8', 'Option D': '6', 'Correct Option': 'Option C'}
# {'Question': 'Which of the following inventions is credited to Marie Curie?', 'Category': 'Science and Technology', 'Option A': 'The light bulb', 'Option B': 'The telephone', 'Option C': 'The X-ray machine', 'Option D': 'The compass', 'Correct Option': 'Option C'}
# {'Question': 'What is the name of the computer programming language that uses a series of logical statements to create algorithms for problem-solving?', 'Category': 'Science and Technology', 'Option A': 'Python', 'Option B': 'JavaScript', 'Option C': 'C++', 'Option D': 'Java', 'Correct Option': 'Option C'}
# {'Question': 'What is considered the smallest unit of measurement in the metric system?', 'Category': 'Science and Technology', 'Option A': 'Centimeter', 'Option B': 'Millimeter', 'Option C': 'Micrometer', 'Option D': 'Nanometer', 'Correct Option': 'Option B'}
# {'Question': 'In which year was the first iPhone released?', 'Category': 'Science and Technology', 'Option A': '2006', 'Option B': '2007', 'Option C': '2008', 'Option D': '2010', 'Correct Option': 'Option B'}
# {'Question': 'Which of the following is a renewable energy source?', 'Category': 'Science and Technology', 'Option A': 'Coal', 'Option B': 'Solar', 'Option C': 'Natural Gas', 'Option D': 'Oil', 'Correct Option': 'Option B'}
# Similar exitss
# {'Question': 'Which of the following is considered the building blocks of all matter?', 'Category': 'Science and Technology', 'Option A': 'Atoms', 'Option B': 'Cells', 'Option C': 'Genes', 'Option D': 'Protons', 'Correct Option': 'Option A'}
# {'Question': 'Which of the following inventions is considered to be the precursor to modern computers?', 'Category': 'Science and Technology', 'Option A': 'The abacus', 'Option B': 'The printing press', 'Option C': 'The steam engine', 'Option D': 'The telescope', 'Correct Option': 'Option A'}
# {'Question': 'How many planets are in our solar system?', 'Category': 'Science and Technology', 'Option A': '6', 'Option B': '8', 'Option C': '10', 'Option D': '12', 'Correct Option': 'Option B'}
# Error: OpenAI response is not formatted correctly.
# {'Question': 'What is the process by which light energy from the sun is converted into chemical energy in plants?', 'Category': 'Science and Technology', 'Option A': 'Photosynthesis', 'Option B': 'Respiration', 'Option C': 'Fermentation', 'Option D': 'Combustion', 'Correct Option': 'Option A'}
# Similar exitss
# Similar exitss
# {'Question': 'What is the process by which cells convert glucose into energy?', 'Category': 'Science and Technology', 'Option A': 'Glycolysis', 'Option B': 'Photosynthesis', 'Option C': 'Metamorphosis', 'Option D': 'Meiosis', 'Correct Option': 'Option A'}
# Similar exitss
# {'Question': 'Who is often referred to as the "father of genetics"?', 'Category': 'Science and Technology', 'Option A': 'Albert Einstein', 'Option B': 'Charles Darwin', 'Option C': 'Gregor Mendel', 'Option D': 'Isaac Newton', 'Correct Option': 'Option C'}
# Similar exitss
# {'Question': 'What is the name of the first satellite launched into space?', 'Category': 'Science and Technology', 'Option A': 'Explorer 1', 'Option B': 'Sputnik 1', 'Option C': 'Telstar 1', 'Option D': 'Vanguard 1', 'Correct Option': 'Option B'}
# Similar exitss
# {'Question': 'What is the process by which cells use oxygen and nutrients to create energy in living organisms?', 'Category': 'Science and Technology', 'Option A': 'Photosynthesis', 'Option B': 'Respiration', 'Option C': 'Reproduction', 'Option D': 'Fermentation', 'Correct Option': 'Option B'}
# {'Question': 'Who invented the World Wide Web?', 'Category': 'Science and Technology', 'Option A': 'Tim Berners-Lee', 'Option B': 'Steve Jobs', 'Option C': 'Bill Gates', 'Option D': 'Mark Zuckerberg', 'Correct Option': 'Option A'}
# Error: OpenAI response is not formatted correctly.
# {'Question': 'What is the abbreviation for the programming language used for creating websites?', 'Category': 'Science and Technology', 'Option A': 'HTML', 'Option B': 'URL', 'Option C': 'CSS', 'Option D': 'HTTPS', 'Correct Option': 'Option A'}
# Similar exitss
# {'Question': 'What is the smallest unit of life?', 'Category': 'Science and Technology', 'Option A': 'Cell', 'Option B': 'Atom', 'Option C': 'Molecule', 'Option D': 'Organ', 'Correct Option': 'Option A'}
# {'Question': 'What is the process by which sound is amplified in a microphone?', 'Category': 'Science and Technology', 'Option A': 'Reflection', 'Option B': 'Refraction', 'Option C': 'Amplification', 'Option D': 'Absorption', 'Correct Option': 'Option C'}
# {'Question': 'Which scientist is known for discovering the concept of gravity?', 'Category': 'Science and Technology', 'Option A': 'Isaac Newton', 'Option B': 'Albert Einstein', 'Option C': 'Marie Curie', 'Option D': 'Charles Darwin', 'Correct Option': 'Option A'}
# Similar exitss
# {'Question': 'What famous scientist discovered the theory of relativity?', 'Category': 'Science and Technology', 'Option A': 'Isaac Newton', 'Option B': 'Albert Einstein', 'Option C': 'Charles Darwin', 'Option D': 'Marie Curie', 'Correct Option': 'Option B'}
# Similar exitss
# {'Question': 'In which year did the first successful human cloning take place?', 'Category': 'Science and Technology', 'Option A': '1997', 'Option B': '2001', 'Option C': '2005', 'Option D': '2009', 'Correct Option': 'Option A'}
# Similar exitss
# {'Question': 'What is the process of converting sunlight into electricity called?', 'Category': 'Science and Technology', 'Option A': 'Solar radiation', 'Option B': 'Solar energy', 'Option C': 'Solar power', 'Option D': 'Solar conversion', 'Correct Option': 'Option C'}
# {'Question': 'What is the largest internal organ in the human body?', 'Category': 'Science and Technology', 'Option A': 'Kidney', 'Option B': 'Liver', 'Option C': 'Brain', 'Option D': 'Heart', 'Correct Option': 'Option B'}
# {'Question': 'Who invented the first functional telephone?', 'Category': 'Science and Technology', 'Option A': 'Alexander Graham Bell', 'Option B': 'Thomas Edison', 'Option C': 'Nikola Tesla', 'Option D': 'Marie Curie', 'Correct Option': 'Option A'}
# Similar exitss
# Similar exitss
# {'Question': 'Who invented the first commercially successful light bulb?', 'Category': 'Science and Technology', 'Option A': 'Thomas Edison', 'Option B': 'Alexander Graham Bell', 'Option C': 'Marie Curie', 'Option D': 'Albert Einstein', 'Correct Option': 'Option A'}
# Similar exitss
# {'Question': 'Who is known as the "father of modern physics"?', 'Category': 'Science and Technology', 'Option A': 'Albert Einstein', 'Option B': 'Isaac Newton', 'Option C': 'Galileo Galilei', 'Option D': 'Stephen Hawking', 'Correct Option': 'Option A'}
# {'Question': "What is the most abundant gas in Earth's atmosphere?", 'Category': 'Science and Technology', 'Option A': 'Nitrogen', 'Option B': 'Oxygen', 'Option C': 'Carbon dioxide', 'Option D': 'Argon', 'Correct Option': 'Option A'}
# Similar exitss
# {'Question': 'What is the smallest unit of measurement used to measure the length of an atom?', 'Category': 'Science and Technology', 'Option A': 'Micrometer', 'Option B': 'Nanometer', 'Option C': 'Centimeter', 'Option D': 'Millimeter', 'Correct Option': 'Option B'}
# Similar exitss
# Similar exitss
# Similar exitss
# Similar exitss
# Similar exitss
# Similar exitss
# {'Question': 'When was the first personal computer released?', 'Category': 'Science and Technology', 'Option A': '1976', 'Option B': '1981', 'Option C': '1984', 'Option D': '1990', 'Correct Option': 'Option A'}
# Similar exitss
# {'Question': "Which of the following is a major component of a computer's central processing unit (CPU)?", 'Category': 'Science and Technology', 'Option A': 'RAM', 'Option B': 'Hard drive', 'Option C': 'Power supply', 'Option D': 'Motherboard', 'Correct Option': 'Option A'}
# Similar exitss
# Similar exitss
# Similar exitss
# Similar exitss
# {'Question': 'Which of the following inventions is credited to Thomas Edison?', 'Category': 'Science and Technology', 'Option A': 'Telephone', 'Option B': 'Light bulb', 'Option C': 'Automobile', 'Option D': 'Airplane', 'Correct Option': 'Option B'}
# Similar exitss
# {'Question': 'What is the largest planet in our solar system?', 'Category': 'Science and Technology', 'Option A': 'Saturn', 'Option B': 'Jupiter', 'Option C': 'Neptune', 'Option D': 'Venus', 'Correct Option': 'Option B'}
# Similar exitss
# Similar exitss
# {'Question': 'What is the smallest unit of matter that retains the properties of an element?', 'Category': 'Science and Technology', 'Option A': 'Atom', 'Option B': 'Molecule', 'Option C': 'Cell', 'Option D': 'Particle', 'Correct Option': 'Option A'}
# Similar exitss
# {'Question': "What is the smallest unit of measurement used to measure the size of a computer's memory?", 'Category': 'Science and Technology', 'Option A': 'Gigabyte', 'Option B': 'Kilobyte', 'Option C': 'Megabyte', 'Option D': 'Terabyte', 'Correct Option': 'Option B'}
# {'Question': 'What is the process of converting seawater into drinking water called?', 'Category': 'Science and Technology', 'Option A': 'Distillation', 'Option B': 'Desalination', 'Option C': 'Filtration', 'Option D': 'Purification', 'Correct Option': 'Option B'}
# Similar exitss
# Similar exitss
# Similar exitss
# Similar exitss
# {'Question': "The study of the Earth's atmosphere and how it affects weather and climate is known as:", 'Category': 'Science and Technology', 'Option A': 'Psychology', 'Option B': 'Meteorology', 'Option C': 'Sociology', 'Option D': 'Biology', 'Correct Option': 'Option B'}
# Similar exitss
# Similar exitss
# {'Question': 'What element has the chemical symbol "Fe"?', 'Category': 'Science and Technology', 'Option A': 'Iron', 'Option B': 'Fluorine', 'Option C': 'Calcium', 'Option D': 'Gold', 'Correct Option': 'Option A'}
# Similar exitss
# Similar exitss
# Similar exitss
# {'Question': 'What is the term used to describe the process of turning data into meaningful information through analysis and interpretation?', 'Category': 'Science and Technology', 'Option A': 'Data mining', 'Option B': 'Data visualization', 'Option C': 'Data transformation', 'Option D': 'Data integration', 'Correct Option': 'Option A'}
# {'Question': 'Which of the following elements is responsible for the red color in rubies?', 'Category': 'Science and Technology', 'Option A': 'Iron', 'Option B': 'Chromium', 'Option C': 'Carbon', 'Option D': 'Copper', 'Correct Option': 'Option B'}
# Similar exitss
# {'Question': 'Which of the following components is responsible for storing and retrieving data in a computer system?', 'Category': 'Science and Technology', 'Option A': 'CPU', 'Option B': 'RAM', 'Option C': 'Hard drive', 'Option D': 'Motherboard', 'Correct Option': 'Option C'}
# {'Question': 'In which year did World War II officially end?', 'Category': 'Historical Events', 'Option A': '1939', 'Option B': '1945', 'Option C': '1949', 'Option D': '1953', 'Correct Option': 'Option B'}
# {'Question': 'Who was the first female Prime Minister of the United Kingdom?', 'Category': 'Historical Events', 'Option A': 'Margaret Thatcher', 'Option B': 'Queen Elizabeth II', 'Option C': 'Theresa May', 'Option D': 'Angela Merkel', 'Correct Option': 'Option A'}
# Similar exitss
# {'Question': 'In which year did the Berlin Wall fall, marking the end of the Cold War?', 'Category': 'Historical Events', 'Option A': '1989', 'Option B': '1991', 'Option C': '1993', 'Option D': '1987', 'Correct Option': 'Option A'}
# Similar exitss
# {'Question': 'Which historical figure is credited with inventing the printing press and revolutionizing the spread of information in Europe during the 15th century?', 'Category': 'Historical Events', 'Option A': 'Leonardo da Vinci', 'Option B': 'Johannes Gutenberg', 'Option C': 'William Shakespeare', 'Option D': 'Christopher Columbus', 'Correct Option': 'Option B'}
# Similar exitss
# Similar exitss
# {'Question': 'In what year did the United States declare its independence?', 'Category': 'Historical Events', 'Option A': '1776', 'Option B': '1796', 'Option C': '1876', 'Option D': '1976', 'Correct Option': 'Option A'}
# Similar exitss
# {'Question': 'Who was the first president of the United States?', 'Category': 'Historical Events', 'Option A': 'George Washington', 'Option B': 'Thomas Jefferson', 'Option C': 'John Adams', 'Option D': 'Abraham Lincoln', 'Correct Option': 'Option A'}
# Similar exitss
# {'Question': 'In what year did the United States enter World War II?', 'Category': 'Historical Events', 'Option A': '1918', 'Option B': '1939', 'Option C': '1941', 'Option D': '1945', 'Correct Option': 'Option C'}
# {'Question': 'In what year did the British East India Company gain control of India?', 'Category': 'Historical Events', 'Option A': '1642', 'Option B': '1858', 'Option C': '1787', 'Option D': '1914', 'Correct Option': 'Option B'}
# Similar exitss
# Similar exitss
# Similar exitss
# {'Question': 'Who was the first female pilot to fly solo across the Atlantic Ocean?', 'Category': 'Historical Events', 'Option A': 'Amelia Earhart', 'Option B': 'Bessie Coleman', 'Option C': 'Sally Ride', 'Option D': 'Jane Austen', 'Correct Option': 'Option A'}
# Similar exitss
# Similar exitss
# Similar exitss
# Similar exitss
# Similar exitss
# {'Question': 'Who was the first female astronaut to travel to space?', 'Category': 'Historical Events', 'Option A': 'Sally Ride', 'Option B': 'Valentina Tereshkova', 'Option C': 'Mae Jemison', 'Option D': 'Kalpana Chawla', 'Correct Option': 'Option B'}
# {'Question': 'What event sparked the start of World War II?', 'Category': 'Historical Events', 'Option A': 'Assassination of Archduke Franz Ferdinand', 'Option B': 'Attack on Pearl Harbor', 'Option C': 'Treaty of Versailles', 'Option D': 'Invasion of Poland', 'Correct Option': 'Option D'}
# {'Question': 'Which famous president delivered the Gettysburg Address during the American Civil War?', 'Category': 'Historical Events', 'Option A': 'Abraham Lincoln', 'Option B': 'George Washington', 'Option C': 'Thomas Jefferson', 'Option D': 'John Adams', 'Correct Option': 'Option A'}
# {'Question': 'Who was the first female to win a Nobel Prize?', 'Category': 'Historical Events', 'Option A': 'Marie Curie', 'Option B': 'Amelia Earhart', 'Option C': 'Rosa Parks', 'Option D': 'Queen Elizabeth I', 'Correct Option': 'Option A'}
# Similar exitss
# Similar exitss
# Similar exitss
# Similar exitss
# Similar exitss
# Similar exitss
# Similar exitss
# Similar exitss
# Similar exitss
# {'Question': 'Which country was the first to launch a man-made satellite into orbit?', 'Category': 'Historical Events', 'Option A': 'United States', 'Option B': 'Russia', 'Option C': 'China', 'Option D': 'Japan', 'Correct Option': 'Option B'}
# Similar exitss
# {'Question': 'In what year did the Civil Rights Act, which prohibited discrimination based on race, color, religion, sex, or national origin, become law in the United States?', 'Category': 'Historical Events', 'Option A': '1964', 'Option B': '1956', 'Option C': '1976', 'Option D': '1986', 'Correct Option': 'Option A'}
# {'Question': 'What event marked the end of World War I?', 'Category': 'Historical Events', 'Option A': 'The signing of the Treaty of Versailles', 'Option B': 'The bombing of Pearl Harbor', 'Option C': 'The Battle of Stalingrad', 'Option D': 'The sinking of the Titanic', 'Correct Option': 'Option A'}
# {'Question': 'Which country was the first to reach the moon?', 'Category': 'Historical Events', 'Option A': 'United States', 'Option B': 'Russia', 'Option C': 'China', 'Option D': 'Japan', 'Correct Option': 'Option A'}
# {'Question': 'Which well-known historical figure was responsible for the construction of the Great Wall of China?', 'Category': 'Historical Events', 'Option A': 'Julius Caesar', 'Option B': 'Alexander the Great', 'Option C': 'Genghis Khan', 'Option D': 'Cleopatra', 'Correct Option': 'Option C'}
# Similar exitss
# {'Question': 'Which of the following historical figures is known for writing the influential document, "Common Sense"?', 'Category': 'Historical Events', 'Option A': 'George Washington', 'Option B': 'Thomas Jefferson', 'Option C': 'Benjamin Franklin', 'Option D': 'Thomas Paine', 'Correct Option': 'Option D'}
# {'Question': 'Which famous historical figure is associated with the quote, "I have a dream"?', 'Category': 'Historical Events', 'Option A': 'Martin Luther King Jr.', 'Option B': 'Abraham Lincoln', 'Option C': 'Winston Churchill', 'Option D': 'Mahatma Gandhi', 'Correct Option': 'Option A'}
# Similar exitss
# Similar exitss
# Similar exitss
# {'Question': 'Which famous speech by Martin Luther King Jr. is considered one of the defining moments of the Civil Rights Movement in the United States?', 'Category': 'Historical Events', 'Option A': '"I Have a Dream"', 'Option B': '"Letter from Birmingham Jail"', 'Option C': '"I\'ve Been to the Mountaintop"', 'Option D': '"The Ballot or the Bullet"', 'Correct Option': 'Option A'}
# {'Question': 'In what year did the United States ratify the 19th Amendment, granting women the right to vote?', 'Category': 'Historical Events', 'Option A': '1919', 'Option B': '1920', 'Option C': '1921', 'Option D': '1922', 'Correct Option': 'Option B'}
# {'Question': 'In which year did the Battle of Gettysburg take place during the American Civil War?', 'Category': 'Historical Events', 'Option A': '1860', 'Option B': '1861', 'Option C': '1862', 'Option D': '1863', 'Correct Option': 'Option D'}
# Similar exitss
# Similar exitss
# {'Question': 'Which historical event marked the beginning of the American Revolution?', 'Category': 'Historical Events', 'Option A': 'The Boston Tea Party', 'Option B': 'The Stamp Act', 'Option C': 'The Boston Massacre', 'Option D': 'The Intolerable Acts', 'Correct Option': 'Option C'}
# Similar exitss
# Similar exitss
# Similar exitss
# Similar exitss
# Similar exitss
# Similar exitss
# {'Question': 'Which European country was not part of the Allies during World War II?', 'Category': 'Historical Events', 'Option A': 'Italy', 'Option B': 'Germany', 'Option C': 'Norway', 'Option D': 'France', 'Correct Option': 'Option B'}
# Error: OpenAI response is not formatted correctly.
# Similar exitss
# Similar exitss
# Similar exitss
# Similar exitss
# {'Question': 'What year did Martin Luther King Jr. deliver his iconic "I Have a Dream" speech during the March on Washington?', 'Category': 'Historical Events', 'Option A': '1963', 'Option B': '1965', 'Option C': '1968', 'Option D': '1972', 'Correct Option': 'Option A'}
# Similar exitss
# Error: OpenAI response is not formatted correctly.
# Similar exitss
# Similar exitss
# Similar exitss
# {'Question': 'Which of the following leaders was not a part of the Potsdam Conference held in 1945 to discuss the division of post-war Europe?', 'Category': 'Historical Events', 'Option A': 'Winston Churchill', 'Option B': 'Franklin D. Roosevelt', 'Option C': 'Joseph Stalin', 'Option D': 'Charles de Gaulle', 'Correct Option': 'Option D'}
# {'Question': 'What was the purpose of the Emancipation Proclamation issued by President Abraham Lincoln during the American Civil War?', 'Category': 'Historical Events', 'Option A': 'To declare war on the Confederate States of America', 'Option B': 'To abolish slavery throughout the United States', 'Option C': 'To establish the first national holiday in the United States', 'Option D': "To expand the United States' territory into the western regions", 'Correct Option': 'Option B'}
# Similar exitss
# Similar exitss
# Similar exitss
# Similar exitss
# Error: OpenAI response is not formatted correctly.
# {'Question': 'Which country was responsible for the construction of the Great Wall of China?', 'Category': 'Historical Events', 'Option A': 'Japan', 'Option B': 'Mongolia', 'Option C': 'China', 'Option D': 'India', 'Correct Option': 'Option C'}
# Similar exitss
# Similar exitss
# Similar exitss
# Similar exitss
# {'Question': 'Which US president signed the Emancipation Proclamation, officially abolishing slavery in the country?', 'Category': 'Historical Events', 'Option A': 'Abraham Lincoln', 'Option B': 'George Washington', 'Option C': 'Thomas Jefferson', 'Option D': 'Andrew Jackson', 'Correct Option': 'Option A'}
# Similar exitss
# Similar exitss
# Similar exitss
# Similar exitss
# Similar exitss
# Similar exitss
# {'Question': 'Which event marked the beginning of the American Civil War?', 'Category': 'Historical Events', 'Option A': 'The Battle of Gettysburg', 'Option B': 'The Emancipation Proclamation', 'Option C': 'The Attack on Fort Sumter', 'Option D': 'The Surrender at Appomattox Courthouse', 'Correct Option': 'Option C'}
# Similar exitss
# Similar exitss
# Similar exitss
# Similar exitss
# Similar exitss
# Similar exitss
# Error: OpenAI response is not formatted correctly.
# Similar exitss
# Similar exitss
# Similar exitss
# {'Question': 'Which president delivered the famous "I Have a Dream" speech during the March on Washington for Jobs and Freedom in 1963?', 'Category': 'Historical Events', 'Option A': 'John F. Kennedy', 'Option B': 'Lyndon B. Johnson', 'Option C': 'Richard Nixon', 'Option D': 'Martin Luther King Jr.', 'Correct Option': 'Option D'}
# {'Question': 'During what year did Christopher Columbus first set foot on the island of Hispaniola?', 'Category': 'Historical Events', 'Option A': '1492', 'Option B': '1493', 'Option C': '1494', 'Option D': '1495', 'Correct Option': 'Option A'}
# Similar exitss
# Similar exitss
# Similar exitss
# Similar exitss
# {'Question': 'In what year did the Korean War begin?', 'Category': 'Historical Events', 'Option A': '1950', 'Option B': '1953', 'Option C': '1960', 'Option D': '1945', 'Correct Option': 'Option A'}
# Similar exitss
# Similar exitss
# Similar exitss
# Similar exitss
# {'Question': 'When did the American Civil War end?', 'Category': 'Historical Events', 'Option A': '1865', 'Option B': '1877', 'Option C': '1899', 'Option D': '1905', 'Correct Option': 'Option A'}
# Similar exitss
# Similar exitss
# {'Question': 'What famous historical event was sparked by the assassination of Archduke Franz Ferdinand?', 'Category': 'Historical Events', 'Option A': 'World War I', 'Option B': 'The French Revolution', 'Option C': 'The American Civil War', 'Option D': 'The Holocaust', 'Correct Option': 'Option A'}
# {'Question': 'Which historical event took place on June 6, 1944?', 'Category': 'Historical Events', 'Option A': 'The bombing of Pearl Harbor', 'Option B': 'The signing of the Declaration of Independence', 'Option C': 'The sinking of the Titanic', 'Option D': 'The invasion of Normandy', 'Correct Option': 'Option D'}
# Similar exitss
# Similar exitss
# {'Question': 'In what year did the United Nations officially come into existence?', 'Category': 'Historical Events', 'Option A': '1945', 'Option B': '1955', 'Option C': '1965', 'Option D': '1975', 'Correct Option': 'Option A'}
# {'Question': 'Who was the first African American woman to win an individual Olympic gold medal?', 'Category': 'Historical Events', 'Option A': 'Florence Griffith-Joyner', 'Option B': 'Wilma Rudolph', 'Option C': 'Althea Gibson', 'Option D': 'Marion Jones', 'Correct Option': 'Option C'}
# {'Question': 'In which year did the Titanic sink?', 'Category': 'Historical Events', 'Option A': '1912', 'Option B': '1920', 'Option C': '1919', 'Option D': '1908', 'Correct Option': 'Option A'}

# %%
test
# Out:
#     question_id                                           Question  \
# 0            Q0  What year was the first modern Olympic Games h...
# 1            Q1  Who is regarded as the greatest basketball pla...
# 2            Q2  Who holds the record for the most Grand Slam m...
# 3            Q3  Which former professional basketball player wa...
# 4            Q4  In what year did the United States host the Wi...
# ..          ...                                                ...
# 195        Q195  What famous historical event was sparked by th...
# 196        Q196  Which historical event took place on June 6, 1...
# 197        Q197  In what year did the United Nations officially...
# 198        Q198  Who was the first African American woman to wi...
# 199        Q199                In which year did the Titanic sink?
#
#               Category                     Option A  \
# 0               Sports                         1912
# 1               Sports               Michael Jordan
# 2               Sports                Roger Federer
# 3               Sports               Michael Jordan
# 4               Sports                         1960
# ..                 ...                          ...
# 195  Historical Events                  World War I
# 196  Historical Events  The bombing of Pearl Harbor
# 197  Historical Events                         1945
# 198  Historical Events     Florence Griffith-Joyner
# 199  Historical Events                         1912
#
#                                            Option B  \
# 0                                              1896
# 1                                      LeBron James
# 2                                      Rafael Nadal
# 3                                       Kobe Bryant
# 4                                              1972
# ..                                              ...
# 195                           The French Revolution
# 196  The signing of the Declaration of Independence
# 197                                            1955
# 198                                   Wilma Rudolph
# 199                                            1920
#
#                        Option C                  Option D Correct Option
# 0                          1908                      1924       Option B
# 1                   Kobe Bryant                Larry Bird       Option A
# 2                Novak Djokovic               Andy Murray       Option A
# 3                  LeBron James                Larry Bird       Option B
# 4                          1980                      1996       Option C
# ..                          ...                       ...            ...
# 195      The American Civil War             The Holocaust       Option A
# 196  The sinking of the Titanic  The invasion of Normandy       Option D
# 197                        1965                      1975       Option A
# 198               Althea Gibson              Marion Jones       Option C
# 199                        1919                      1908       Option A
#
# [200 rows x 8 columns]
